# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# get matplot to show charts inline
# %matplotlib inline

# %% [markdown]
# chrome://settings/content/cookies
#
# NOTE: Make sure third party cookies are not blocked.

# %%
from google.colab import files
uploaded = files.upload()
import io
df = pd.read_csv(io.BytesIO(uploaded["Employee-attrition.csv"]))
# Out:
#      <input type="file" id="files-6de949e7-4149-4647-ad27-1979d412a2f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6de949e7-4149-4647-ad27-1979d412a2f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Employee-attrition.csv to Employee-attrition.csv

# %%
df.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key  ... STATUS_YEAR  STATUS  BUSINESS_UNIT
# 0        1318  12/31/2006 0:00      1/3/1954  ...        2006  ACTIVE     HEADOFFICE
# 1        1318  12/31/2007 0:00      1/3/1954  ...        2007  ACTIVE     HEADOFFICE
# 2        1318  12/31/2008 0:00      1/3/1954  ...        2008  ACTIVE     HEADOFFICE
# 3        1318  12/31/2009 0:00      1/3/1954  ...        2009  ACTIVE     HEADOFFICE
# 4        1318  12/31/2010 0:00      1/3/1954  ...        2010  ACTIVE     HEADOFFICE
#
# [5 rows x 18 columns]

# %%
df.tail()
# Out:
#        EmployeeID  recorddate_key  ...      STATUS BUSINESS_UNIT
# 49648        8258  12/1/2015 0:00  ...  TERMINATED        STORES
# 49649        8264   8/1/2013 0:00  ...  TERMINATED        STORES
# 49650        8279  12/1/2015 0:00  ...  TERMINATED        STORES
# 49651        8296  12/1/2013 0:00  ...  TERMINATED        STORES
# 49652        8321  12/1/2014 0:00  ...  TERMINATED        STORES
#
# [5 rows x 18 columns]

# %% [markdown]
# # Accessing the main DataFrame components

# %%
columns = df.columns
index = df.index
data = df.values

# %%
columns
# Out:
# Index(['EmployeeID', 'recorddate_key', 'birthdate_key', 'orighiredate_key',
#        'terminationdate_key', 'age', 'length_of_service', 'city_name',
#        'department_name', 'job_title', 'store_name', 'gender_short',
#        'gender_full', 'termreason_desc', 'termtype_desc', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
index
# Out:
# RangeIndex(start=0, stop=49653, step=1)

# %%
data
# Out:
# array([[1318, '12/31/2006 0:00', '1/3/1954', ..., 2006, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2007 0:00', '1/3/1954', ..., 2007, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2008 0:00', '1/3/1954', ..., 2008, 'ACTIVE',
#         'HEADOFFICE'],
#        ...,
#        [8279, '12/1/2015 0:00', '7/18/1994', ..., 2015, 'TERMINATED',
#         'STORES'],
#        [8296, '12/1/2013 0:00', '9/2/1994', ..., 2013, 'TERMINATED',
#         'STORES'],
#        [8321, '12/1/2014 0:00', '11/28/1994', ..., 2014, 'TERMINATED',
#         'STORES']], dtype=object)

# %% [markdown]
# # 1. Understanding Data Types

# %% [markdown]
# #### 1.A Find Shape of Data Frame

# %%
# A:
df.shape
# Out:
# (49653, 18)

# %% [markdown]
# #### 1.B Find Data Tyeps of Data Frame

# %%
# A:
df.dtypes
# Out:
# EmployeeID              int64
# recorddate_key         object
# birthdate_key          object
# orighiredate_key       object
# terminationdate_key    object
# age                     int64
# length_of_service       int64
# city_name              object
# department_name        object
# job_title              object
# store_name              int64
# gender_short           object
# gender_full            object
# termreason_desc        object
# termtype_desc          object
# STATUS_YEAR             int64
# STATUS                 object
# BUSINESS_UNIT          object
# dtype: object

# %% [markdown]
# #### 1.C Find Number of Data Types in a Data Frame
#
#
#
# ```
# Expected Output:
# int64      5
# object    13
# dtype: int64
# ```

# %%
df.dtypes.value_counts()
# Out:
# object    13
# int64      5
# dtype: int64

# %% [markdown]
# #### 1.D Use Info
#
# Use info and explore difference.

# %%
# A:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49653 entries, 0 to 49652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           49653 non-null  int64
#  1   recorddate_key       49653 non-null  object
#  2   birthdate_key        49653 non-null  object
#  3   orighiredate_key     49653 non-null  object
#  4   terminationdate_key  49653 non-null  object
#  5   age                  49653 non-null  int64
#  6   length_of_service    49653 non-null  int64
#  7   city_name            49653 non-null  object
#  8   department_name      49653 non-null  object
#  9   job_title            49653 non-null  object
#  10  store_name           49653 non-null  int64
#  11  gender_short         49653 non-null  object
#  12  gender_full          49653 non-null  object
#  13  termreason_desc      49653 non-null  object
#  14  termtype_desc        49653 non-null  object
#  15  STATUS_YEAR          49653 non-null  int64
#  16  STATUS               49653 non-null  object
#  17  BUSINESS_UNIT        49653 non-null  object
# dtypes: int64(5), object(13)
# memory usage: 6.8+ MB

# %% [markdown]
# # 2. Selecting Column in Data Frame

# %% [markdown]
# #### 2.A Check Values of Job_Title column

# %%
# A:
df['job_title']
# Out:
# 0                 CEO
# 1                 CEO
# 2                 CEO
# 3                 CEO
# 4                 CEO
#              ...
# 49648    Dairy Person
# 49649         Cashier
# 49650         Cashier
# 49651         Cashier
# 49652         Cashier
# Name: job_title, Length: 49653, dtype: object

# %% [markdown]
# #### 2.B Find How Many Rows Are in Each Job Title
#
#
#
# ```
# # Expected Output
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# .
# .
# .
# ```

# %%
df['job_title'].value_counts()
# Out:
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# Baker                              8096
# Cashier                            6816
# Shelf Stocker                      5622
# Customer Service Manager            306
# Processed Foods Manager             289
# Meats Manager                       285
# Bakery Manager                      285
# Produce Manager                     278
# Store Manager                       271
# Recruiter                            62
# HRIS Analyst                         55
# Accounting Clerk                     50
# Benefits Admin                       35
# Labor Relations Analyst              30
# Accounts Receiveable Clerk           30
# Trainer                              26
# Accounts Payable Clerk               25
# Auditor                              20
# Compensation Analyst                 20
# Systems Analyst                      20
# Investment Analyst                   20
# Corporate Lawyer                     17
# Legal Counsel                        10
# Director, Recruitment                10
# CHief Information Officer            10
# CEO                                  10
# VP Finance                           10
# Exec Assistant, Human Resources      10
# Exec Assistant, Legal Counsel        10
# Exec Assistant, Finance              10
# VP Human Resources                   10
# Exec Assistant, VP Stores            10
# VP Stores                            10
# Dairy Manager                         9
# Director, Accounts Receivable         9
# Director, Employee Records            9
# Director, Accounting                  9
# Director, HR Technology               9
# Director, Accounts Payable            9
# Director, Compensation                4
# Director, Investments                 4
# Director, Audit                       4
# Director, Training                    4
# Director, Labor Relations             4
# Name: job_title, dtype: int64

# %% [markdown]
# #### 2.C [BONUS] Write A Function to Row Count
#
#
#
# ```
# def row_count(column_name):
#     number_of_rows = 0
#     return number_of_rows
# ```

# %%
def row_count(column_name):
    number_of_rows = df[column_name].value_counts()
    return number_of_rows

print(row_count('job_title'))
# Out:
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# Baker                              8096
# Cashier                            6816
# Shelf Stocker                      5622
# Customer Service Manager            306
# Processed Foods Manager             289
# Meats Manager                       285
# Bakery Manager                      285
# Produce Manager                     278
# Store Manager                       271
# Recruiter                            62
# HRIS Analyst                         55
# Accounting Clerk                     50
# Benefits Admin                       35
# Labor Relations Analyst              30
# Accounts Receiveable Clerk           30
# Trainer                              26
# Accounts Payable Clerk               25
# Auditor                              20
# Compensation Analyst                 20
# Systems Analyst                      20
# Investment Analyst                   20
# Corporate Lawyer                     17
# Legal Counsel                        10
# Director, Recruitment                10
# CHief Information Officer            10
# CEO                                  10
# VP Finance                           10
# Exec Assistant, Human Resources      10
# Exec Assistant, Legal Counsel        10
# Exec Assistant, Finance              10
# VP Human Resources                   10
# Exec Assistant, VP Stores            10
# VP Stores                            10
# Dairy Manager                         9
# Director, Accounts Receivable         9
# Director, Employee Records            9
# Director, Accounting                  9
# Director, HR Technology               9
# Director, Accounts Payable            9
# Director, Compensation                4
# Director, Investments                 4
# Director, Audit                       4
# Director, Training                    4
# Director, Labor Relations             4
# Name: job_title, dtype: int64

# %% [markdown]
# #### 2.D Describe 'Age'
#
# Find count,  mean,  std, min, max of column 'age'

# %%
# A:
df['age'].describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %% [markdown]
# ##### 2.E [BONUS] Describe 'All Numeric Columns of Data Frame
#
# Find count, mean, std, min, max of of all columns of dataframe

# %%
# A:
df.describe()
# Out:
#          EmployeeID           age  ...    store_name   STATUS_YEAR
# count  49653.000000  49653.000000  ...  49653.000000  49653.000000
# mean    4859.495740     42.077035  ...     27.297605   2010.612612
# std     1826.571142     12.427257  ...     13.514134      2.845577
# min     1318.000000     19.000000  ...      1.000000   2006.000000
# 25%     3360.000000     31.000000  ...     16.000000   2008.000000
# 50%     5031.000000     42.000000  ...     28.000000   2011.000000
# 75%     6335.000000     53.000000  ...     42.000000   2013.000000
# max     8336.000000     65.000000  ...     46.000000   2015.000000
#
# [8 rows x 5 columns]

# %% [markdown]
# # 3. Making The Index Meaningful

# %%
# A:

# %% [markdown]
# #### 3.A Find A Specifc Row Using Index

# %%
df[0:5]
# Out:
#    EmployeeID   recorddate_key birthdate_key  ... STATUS_YEAR  STATUS  BUSINESS_UNIT
# 0        1318  12/31/2006 0:00      1/3/1954  ...        2006  ACTIVE     HEADOFFICE
# 1        1318  12/31/2007 0:00      1/3/1954  ...        2007  ACTIVE     HEADOFFICE
# 2        1318  12/31/2008 0:00      1/3/1954  ...        2008  ACTIVE     HEADOFFICE
# 3        1318  12/31/2009 0:00      1/3/1954  ...        2009  ACTIVE     HEADOFFICE
# 4        1318  12/31/2010 0:00      1/3/1954  ...        2010  ACTIVE     HEADOFFICE
#
# [5 rows x 18 columns]

# %% [markdown]
# #### 3.B Sort Data Frame using Index

# %%
df.sort_index()
# Out:
#        EmployeeID   recorddate_key  ...      STATUS BUSINESS_UNIT
# 0            1318  12/31/2006 0:00  ...      ACTIVE    HEADOFFICE
# 1            1318  12/31/2007 0:00  ...      ACTIVE    HEADOFFICE
# 2            1318  12/31/2008 0:00  ...      ACTIVE    HEADOFFICE
# 3            1318  12/31/2009 0:00  ...      ACTIVE    HEADOFFICE
# 4            1318  12/31/2010 0:00  ...      ACTIVE    HEADOFFICE
# ...           ...              ...  ...         ...           ...
# 49648        8258   12/1/2015 0:00  ...  TERMINATED        STORES
# 49649        8264    8/1/2013 0:00  ...  TERMINATED        STORES
# 49650        8279   12/1/2015 0:00  ...  TERMINATED        STORES
# 49651        8296   12/1/2013 0:00  ...  TERMINATED        STORES
# 49652        8321   12/1/2014 0:00  ...  TERMINATED        STORES
#
# [49653 rows x 18 columns]

# %% [markdown]
# #### 3.C [BONUS] Sort Data Frame using Age

# %%
df.sort_values(by=['age'])
# Out:
#        EmployeeID   recorddate_key  ...      STATUS BUSINESS_UNIT
# 48132        8325  12/31/2013 0:00  ...      ACTIVE        STORES
# 47925        8253  12/31/2013 0:00  ...      ACTIVE        STORES
# 47922        8252  12/31/2013 0:00  ...      ACTIVE        STORES
# 47919        8251  12/31/2013 0:00  ...      ACTIVE        STORES
# 47916        8250  12/31/2013 0:00  ...      ACTIVE        STORES
# ...           ...              ...  ...         ...           ...
# 48635        3262    8/1/2008 0:00  ...  TERMINATED        STORES
# 48634        3248    8/1/2008 0:00  ...  TERMINATED        STORES
# 49127        4948    7/1/2013 0:00  ...  TERMINATED        STORES
# 48651        3356   11/1/2008 0:00  ...  TERMINATED        STORES
# 48820        4138    2/1/2011 0:00  ...  TERMINATED        STORES
#
# [49653 rows x 18 columns]

# %% [markdown]
# #### 3.D [BONUS] Using Sample Select Any Row

# %%
# A:
df.sample()
# Out:
#        EmployeeID  recorddate_key  ...      STATUS BUSINESS_UNIT
# 49642        8187  10/1/2014 0:00  ...  TERMINATED        STORES
#
# [1 rows x 18 columns]

# %% [markdown]
# # 4. Query Data Frame
#
# #### 4.A Find Rows Where Job_Title is CEO

# %%
# A:
CEO_data = df[df['job_title'] == 'CEO']
CEO_data
# Out:
#    EmployeeID   recorddate_key birthdate_key  ... STATUS_YEAR  STATUS  BUSINESS_UNIT
# 0        1318  12/31/2006 0:00      1/3/1954  ...        2006  ACTIVE     HEADOFFICE
# 1        1318  12/31/2007 0:00      1/3/1954  ...        2007  ACTIVE     HEADOFFICE
# 2        1318  12/31/2008 0:00      1/3/1954  ...        2008  ACTIVE     HEADOFFICE
# 3        1318  12/31/2009 0:00      1/3/1954  ...        2009  ACTIVE     HEADOFFICE
# 4        1318  12/31/2010 0:00      1/3/1954  ...        2010  ACTIVE     HEADOFFICE
# 5        1318  12/31/2011 0:00      1/3/1954  ...        2011  ACTIVE     HEADOFFICE
# 6        1318  12/31/2012 0:00      1/3/1954  ...        2012  ACTIVE     HEADOFFICE
# 7        1318  12/31/2013 0:00      1/3/1954  ...        2013  ACTIVE     HEADOFFICE
# 8        1318  12/31/2014 0:00      1/3/1954  ...        2014  ACTIVE     HEADOFFICE
# 9        1318  12/31/2015 0:00      1/3/1954  ...        2015  ACTIVE     HEADOFFICE
#
# [10 rows x 18 columns]

# %% [markdown]
# #### 4.B Group By Age

# %%
# A:
df_age = df.groupby('age').mean()
df_age
# Out:
#       EmployeeID  length_of_service  store_name  STATUS_YEAR
# age
# 19   8240.000000           0.000000   25.107595  2012.803797
# 20   8120.522059           0.372549   26.549020  2012.813725
# 21   7979.603129           0.803698   27.139403  2012.738265
# 22   7745.947239           0.938650   27.011043  2011.944785
# 23   7557.972917           1.260417   27.233333  2011.519792
# 24   7366.733573           1.553555   27.329433  2011.068407
# 25   7155.654971           1.800334   27.507937  2010.439432
# 26   7016.394215           2.253719   27.715702  2010.362810
# 27   6889.618623           2.826721   27.485830  2010.384615
# 28   6758.986122           3.329796   27.746939  2010.378776
# 29   6637.653627           3.898941   27.700896  2010.436838
# 30   6520.471947           4.428218   27.802805  2010.511551
# 31   6381.682373           4.945026   27.599476  2010.410995
# 32   6257.544666           5.470945   27.614918  2010.408500
# 33   6133.498282           6.000000   27.601375  2010.405498
# 34   6012.346801           6.546296   27.298822  2010.429293
# 35   5898.017662           7.095879   27.209420  2010.505467
# 36   5781.877551           7.677721   26.724490  2010.560374
# 37   5642.226284           8.106179   26.980853  2010.412533
# 38   5517.976644           8.666955   26.541522  2010.437716
# 39   5383.267951           9.197023   26.825744  2010.462347
# 40   5254.915929           9.779646   26.798230  2010.530973
# 41   5108.611454          10.294273   26.864317  2010.541850
# 42   4937.554688          10.802951   26.994792  2010.431424
# 43   4777.000870          11.293043   27.179130  2010.411304
# 44   4593.939499          11.814175   27.509939  2010.318928
# 45   4441.652936          12.375986   27.524978  2010.425066
# 46   4268.785530          12.925926   27.357450  2010.439276
# 47   4064.146633          13.388747   27.159420  2010.330776
# 48   3876.921186          13.938983   27.606780  2010.328814
# 49   3707.950669          14.494983   27.698997  2010.411371
# 50   3523.208539          15.045156   27.738916  2010.449918
# 51   3342.714996          15.608119   27.597349  2010.505385
# 52   3150.625421          16.117003   27.472222  2010.491582
# 53   2967.174242          16.672559   27.563131  2010.521886
# 54   2788.230371          17.187230   27.358930  2010.558240
# 55   2621.874144          17.774829   27.518836  2010.655822
# 56   2433.334489          18.277296   27.675043  2010.656846
# 57   2234.460177          18.791150   28.064602  2010.578761
# 58   2439.851327          18.134513   27.543363  2010.523009
# 59   2622.679078          17.590426   27.353723  2010.481383
# 60   2779.655546          16.975654   27.121731  2010.443643
# 61   2603.602378          18.630119   27.054161  2011.462351
# 62   2746.280899          18.061798   26.693820  2011.290730
# 63   2904.631184          17.290855   26.293853  2010.950525
# 64   3037.928793          16.642415   26.057276  2010.678019
# 65   3219.317032          15.286678   25.666105  2010.322091

# %% [markdown]
# # 5. Visualization
#
# #### 5.A Plot Histogram of Age

# %%
# A:
plt.hist(df['age'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# #### 5.B BoxPlot of Age

# %%
# A:
plt.boxplot(df['age'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fd1ea535550>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fd1ea535f60>,
#   <matplotlib.lines.Line2D at 0x7fd1ea543320>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd1ea543a20>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd1ea5436a0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fd1ea535860>,
#   <matplotlib.lines.Line2D at 0x7fd1ea535be0>]}

# %% [markdown]
# #### 5.C Scatterplot of age and length_of_service

# %%
# A:
plt.scatter(df['age'],df['length_of_service'])

# %% [markdown]
# #### 5.D Plot Histogram of store_name

# %%
plt.hist(df['store_name'])
# Out:
# (array([ 3403.,  3124.,  1379.,  9351.,  4495.,  2786.,  5698.,  3003.,
#          3689., 12725.]),
#  array([ 1. ,  5.5, 10. , 14.5, 19. , 23.5, 28. , 32.5, 37. , 41.5, 46. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### 5.E Print Statistical Summary of Age

# %%
# A:
df['age'].describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Institute of Data
#
#
# ---
#
#
#
# ---
