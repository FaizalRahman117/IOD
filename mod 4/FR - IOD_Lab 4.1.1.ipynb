# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 4.1.1 Linear Regression

# %% [markdown]
# ## Prediction of House Price Using Linear Regression

# %% [markdown]
# ### Data
#
# The Sacramento real estate transactions file is a list of 985 real estate transactions in the Sacramento area reported over a five-day period, as reported by the Sacramento Bee.

# %%
import pandas as pd
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %% [markdown]
# ### 1. Explore Data

# %% [markdown]
# Perform EDA on this dataset. Use what you have learned so far. Be creative. List all your findings.

# %%
# Read CSV
house_csv = "../DATA/Sacramento_transactions.csv"

house = pd.read_csv(house_csv, header = 0)
house.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %% [markdown]
# #### 1.1 Check for null values

# %%
house.isnull().sum()
# Out:
# street       0
# city         0
# zip          0
# state        0
# beds         0
# baths        0
# sq__ft       0
# type         0
# sale_date    0
# price        0
# latitude     0
# longitude    0
# dtype: int64

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 814 entries, 0 to 984
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   street     814 non-null    object
#  1   city       814 non-null    object
#  2   zip        814 non-null    int64
#  3   state      814 non-null    object
#  4   beds       814 non-null    int64
#  5   baths      814 non-null    int64
#  6   sq__ft     814 non-null    int64
#  7   type       814 non-null    object
#  8   sale_date  814 non-null    object
#  9   price      814 non-null    int64
#  10  latitude   814 non-null    float64
#  11  longitude  814 non-null    float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 82.7+ KB

# %% [markdown]
# No null values

# %% [markdown]
# #### 1.2 Describe numerical values

# %%
house.describe(include = 'all')
# Out:
#                street        city         zip state        beds       baths  \
# count             814         814    814.0000   814  814.000000  814.000000
# unique            811          36         NaN     1         NaN         NaN
# top     4734 14TH AVE  SACRAMENTO         NaN    CA         NaN         NaN
# freq                2         424         NaN   814         NaN         NaN
# mean              NaN         NaN  95761.4914   NaN    3.244472    1.960688
# std               NaN         NaN     85.3440   NaN    0.852137    0.669804
# min               NaN         NaN  95603.0000   NaN    1.000000    1.000000
# 25%               NaN         NaN  95670.0000   NaN    3.000000    2.000000
# 50%               NaN         NaN  95820.0000   NaN    3.000000    2.000000
# 75%               NaN         NaN  95828.0000   NaN    4.000000    2.000000
# max               NaN         NaN  95864.0000   NaN    8.000000    5.000000
#
#              sq__ft         type                     sale_date          price  \
# count    814.000000          814                           814     814.000000
# unique          NaN            3                             5            NaN
# top             NaN  Residential  Fri May 16 00:00:00 EDT 2008            NaN
# freq            NaN          759                           216            NaN
# mean    1591.146192          NaN                           NaN  229448.369779
# std      663.841930          NaN                           NaN  119825.576060
# min      484.000000          NaN                           NaN    2000.000000
# 25%     1144.000000          NaN                           NaN  148750.000000
# 50%     1418.500000          NaN                           NaN  207986.500000
# 75%     1851.000000          NaN                           NaN  284973.250000
# max     5822.000000          NaN                           NaN  884790.000000
#
#           latitude   longitude
# count   814.000000  814.000000
# unique         NaN         NaN
# top            NaN         NaN
# freq           NaN         NaN
# mean     38.577044 -121.378687
# std       0.126315    0.119736
# min      38.241514 -121.550527
# 25%      38.473885 -121.451501
# 50%      38.591720 -121.405456
# 75%      38.674705 -121.325844
# max      39.008159 -120.597599

# %% [markdown]
# -Curious that we have houses that are zero sq_ft, beds and baths. Will need to investigate further
# -Housing prices vary between  1k to 884k, with a mean of 234k, and median of 213k
# -Housing sizes vary from 0 to 5822 sqft, with a mean of 1318 sqft

# %%
house[house['sq__ft'] == 0]
# Out:
#                        street             city    zip state  beds  baths  \
# 73              17 SERASPI CT       SACRAMENTO  95834    CA     0      0
# 89           2866 KARITSA AVE       SACRAMENTO  95833    CA     0      0
# 100     12209 CONSERVANCY WAY   RANCHO CORDOVA  95742    CA     0      0
# 121       5337 DUSTY ROSE WAY   RANCHO CORDOVA  95742    CA     0      0
# 126       2115 SMOKESTACK WAY       SACRAMENTO  95833    CA     0      0
# ..                        ...              ...    ...   ...   ...    ...
# 934  1550 TOPANGA LN Unit 207          LINCOLN  95648    CA     0      0
# 947     1525 PENNSYLVANIA AVE  WEST SACRAMENTO  95691    CA     0      0
# 966          9197 CORTINA CIR        ROSEVILLE  95678    CA     3      2
# 970             3557 SODA WAY       SACRAMENTO  95834    CA     0      0
# 973      2181 WINTERHAVEN CIR     CAMERON PARK  95682    CA     3      2
#
#      sq__ft         type                     sale_date   price   latitude  \
# 73        0  Residential  Wed May 21 00:00:00 EDT 2008  206000  38.631481
# 89        0  Residential  Wed May 21 00:00:00 EDT 2008  244500  38.626671
# 100       0  Residential  Wed May 21 00:00:00 EDT 2008  263500  38.553867
# 121       0  Residential  Wed May 21 00:00:00 EDT 2008  320000  38.528575
# 126       0  Residential  Wed May 21 00:00:00 EDT 2008  339500  38.602416
# ..      ...          ...                           ...     ...        ...
# 934       0        Condo  Thu May 15 00:00:00 EDT 2008  188000  38.884170
# 947       0  Residential  Thu May 15 00:00:00 EDT 2008  200100  38.569943
# 966       0        Condo  Thu May 15 00:00:00 EDT 2008  220000  38.793152
# 970       0  Residential  Thu May 15 00:00:00 EDT 2008  224000  38.631026
# 973       0  Residential  Thu May 15 00:00:00 EDT 2008  224500  38.697570
#
#       longitude
# 73  -121.501880
# 89  -121.525970
# 100 -121.219141
# 121 -121.228600
# 126 -121.542965
# ..          ...
# 934 -121.270222
# 947 -121.527539
# 966 -121.290025
# 970 -121.501879
# 973 -120.995739
#
# [171 rows x 12 columns]

# %% [markdown]
# At 171 rows, this makes up 18% of all observations. Given that housing prices tend to have a dependency on the overall size of the house, we should drop these columns

# %%
delete = house[house['sq__ft'] == 0].index

house.drop(delete, inplace=True)
print(house.head())
print(house.shape)
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768
# (814, 12)

# %%
sns.distplot(house['price'])

# %%
#correlation between variables
sns.heatmap(house.corr(), annot=True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# Nothing significant of note for correlation aside from the fact the number of beds and bath have a high positive correlation

# %% [markdown]
# #### Check categorical unique values for any further anomalies

# %%
print(house['street'].unique())
print(house['city'].unique())
print(house['type'].unique())
# Out:
# ['3526 HIGH ST' '51 OMAHA CT' '2796 BRANCH ST' '2805 JANETTE WAY'
#  '6001 MCMAHON DR' '5828 PEPPERMILL CT' '6048 OGDEN NASH WAY'
#  '2561 19TH AVE' '11150 TRINITY RIVER DR Unit 114' '7325 10TH ST'
#  '645 MORRISON AVE' '4085 FAWN CIR' '2930 LA ROSA RD' '2113 KIRK WAY'
#  '4533 LOCH HAVEN WAY' '7340 HAMDEN PL' '6715 6TH ST'
#  '6236 LONGFORD DR Unit 1' '250 PERALTA AVE' '113 LEEWILL AVE'
#  '6118 STONEHAND AVE' '4882 BANDALIN WAY' '7511 OAKVALE CT' '9 PASTURE CT'
#  '3729 BAINBRIDGE DR' '3828 BLACKFOOT WAY' '4108 NORTON WAY'
#  '1469 JANRICK AVE' '9861 CULP WAY' '7825 CREEK VALLEY CIR'
#  '5201 LAGUNA OAKS DR Unit 140' '6768 MEDORA DR' '3100 EXPLORER DR'
#  '7944 DOMINION WAY' '5201 LAGUNA OAKS DR Unit 162' '3920 SHINING STAR DR'
#  '5031 CORVAIR ST' '7661 NIXOS WAY' '7044 CARTHY WAY' '2442 LARKSPUR LN'
#  '4800 WESTLAKE PKWY Unit 2109' '2178 63RD AVE' '8718 ELK WAY'
#  '5708 RIDGEPOINT DR' '7315 KOALA CT' '2622 ERIN DR' '8421 SUNBLAZE WAY'
#  '7420 ALIX PKWY' '3820 NATOMA WAY' '4431 GREEN TREE DR' '9417 SARA ST'
#  '8299 HALBRITE WAY' '7223 KALLIE KAY LN' '8156 STEINBECK WAY'
#  '7957 VALLEY GREEN DR' '1122 WILD POPPY CT' '4520 BOMARK WAY'
#  '9012 KIEFER BLVD' '5332 SANDSTONE ST' '5993 SAWYER CIR'
#  '4844 CLYDEBANK WAY' '306 CAMELLIA WAY' '9021 MADISON AVE' '404 6TH ST'
#  '8317 SUNNY CREEK WAY' '2617 BASS CT' '7005 TIANT WAY' '7895 CABER WAY'
#  '7624 BOGEY CT' '6930 HAMPTON COVE WAY' '8708 MESA BROOK WAY'
#  '120 GRANT LN' '5907 ELLERSLEE DR' '170 PENHOW CIR'
#  '8345 STAR THISTLE WAY' '9080 FRESCA WAY' '391 NATALINO CIR'
#  '8373 BLACKMAN WAY' '9837 CORTE DORADO CT' '5037 J PKWY'
#  '10245 LOS PALOS DR' '6613 NAVION DR' '2887 AZEVEDO DR'
#  '9186 KINBRACE CT' '4243 MIDDLEBURY WAY' '1028 FALLON PLACE CT'
#  '4804 NORIKER DR' '7713 HARVEST WOODS DR' '6913 RICHEVE WAY'
#  '8636 TEGEA WAY' '5448 MAIDSTONE WAY' '18 OLLIE CT' '4010 ALEX LN'
#  '4901 MILLNER WAY' '4818 BRITTNEY LEE CT' '5529 LAGUNA PARK DR'
#  '230 CANDELA CIR' '4900 71ST ST' '4236 NATOMAS CENTRAL DR'
#  '5615 LUPIN LN' '5625 JAMES WAY' '7842 LAHONTAN CT' '6850 21ST ST'
#  '2900 BLAIR RD' '2064 EXPEDITION WAY' '2912 NORCADE CIR'
#  '9507 SEA CLIFF WAY' '8882 AUTUMN GOLD CT' '5322 WHITE LOTUS WAY'
#  '1838 CASTRO WAY' '10158 CRAWFORD WAY' '7731 MASTERS ST'
#  '4925 PERCHERON DR' '2010 PROMONTORY POINT LN' '4727 SAVOIE WAY'
#  '8664 MAGNOLIA HILL WAY' '9570 HARVEST ROSE WAY' '4359 CREGAN CT'
#  '8929 SUTTERS GOLD DR' '8025 PEERLESS AVE' '4620 WELERA WAY'
#  '9723 TERRAPIN CT' '100 REBECCA WAY' '9488 OAK VILLAGE WAY'
#  '8495 DARTFORD DR' '6708 PONTA DO SOL WAY' '4143 SEA MEADOW WAY'
#  '15300 MURIETA SOUTH PKWY' '11215 SHARRMONT CT' '7105 DANBERG WAY'
#  '5579 JERRY LITELL WAY' '1050 FOXHALL WAY' '7837 ABBINGTON WAY'
#  '1300 F ST' '6801 RAWLEY WAY' '1693 SHELTER COVE DR' '9361 WADDELL LN'
#  '10 SEA FOAM CT' '6945 RIO TEJO WAY' '4186 TULIP PARK WAY'
#  '207 ORANGE BLOSSOM CIR Unit C' '6507 RIO DE ONAR WAY' '7004 RAWLEY WAY'
#  '6503 RIO DE ONAR WAY' '2217 APPALOOSA CT' '4004 CRESTA WAY'
#  '6272 LONGFORD DR Unit 1' '3432 Y ST' '9512 EMERALD PARK DR Unit 3'
#  '3132 CLAY ST' '5221 38TH AVE' '6112 HERMOSA ST' '483 ARCADE BLVD'
#  '671 SONOMA AVE' '5980 79TH ST' '7607 ELDER CREEK RD' '5028 14TH AVE'
#  '1069 ACACIA AVE' '5201 LAGUNA OAKS DR Unit 199' '3847 LAS PASAS WAY'
#  '5201 LAGUNA OAKS DR Unit 172' '1121 CREEKSIDE WAY' '5307 CABRILLO WAY'
#  '3725 DON JULIO BLVD' '4803 MCCLOUD DR' '10542 SILVERWOOD WAY'
#  '6318 39TH AVE' '211 MCDANIEL CIR' '3800 LYNHURST WAY' '6139 HERMOSA ST'
#  '2505 RHINE WAY' '3692 PAYNE WAY' '604 MORRISON AVE' '648 SANTA ANA AVE'
#  '14 ASHLEY OAKS CT' '3174 NORTHVIEW DR' '840 TRANQUIL LN'
#  '5333 PRIMROSE DR Unit 19A' '1035 MILLET WAY' '3328 22ND AVE'
#  '8001 HARTWICK WAY' '7812 HARTWICK WAY' '4207 PAINTER WAY'
#  '7458 WINKLEY WAY' '8354 SUNRISE WOODS WAY' '8116 COTTONMILL CIR'
#  '4660 CEDARWOOD WAY' '9254 HARROGATE WAY' '6716 TAREYTON WAY'
#  '2028 ROBERT WAY' '9346 AIZENBERG CIR' '4524 LOCH HAVEN WAY'
#  '7140 BLUE SPRINGS WAY' '4631 11TH AVE' '3228 BAGGAN CT'
#  '8515 DARTFORD DR' '4500 TIPPWOOD WAY' '2460 EL ROCCO WAY'
#  '8244 SUNBIRD WAY' '5841 VALLEY VALE WAY' '7863 CRESTLEIGH CT'
#  '7129 SPRINGMONT DR' '8284 RED FOX WAY' '2219 EL CANTO CIR'
#  '8907 GEMWOOD WAY' '5925 MALEVILLE AVE' '7031 CANEVALLEY CIR'
#  '3949 WILDROSE WAY' '4437 MITCHUM CT' '8151 QUAIL RIDGE CT'
#  '4899 WIND CREEK DR' '6049 HAMBURG WAY' '4232 71ST ST'
#  '1889 COLD SPRINGS RD' '5805 HIMALAYA WAY' '7944 SYLVAN OAK WAY'
#  '6217 LEOLA WAY' '3035 BRUNNET LN' '3025 EL PRADO WAY'
#  '9387 GRANITE FALLS CT' '9257 CALDERA WAY' '441 ARLINGDALE CIR'
#  '2284 LOS ROBLES RD' '8164 CHENIN BLANC LN' '4620 CHAMBERLIN CIR'
#  '5340 BIRK WAY' '51 ANJOU CIR' '2125 22ND AVE' '7344 BUTTERBALL WAY'
#  '8219 GWINHURST CIR' '3240 S ST' '5706 GREENACRES WAY' '6900 LONICERA DR'
#  '419 DAWNRIDGE RD' '5312 MARBURY WAY' '6344 BONHAM CIR'
#  '8207 YORKTON WAY' '7922 MANSELL WAY' '5712 MELBURY CIR'
#  '1570 GLIDDEN AVE' '8108 FILIFERA WAY' '5342 CALABRIA WAY'
#  '47 NAPONEE CT' '8864 REMBRANT CT' '9455 SEA CLIFF WAY'
#  '9720 LITTLE HARBOR WAY' '8806 PHOENIX AVE' '3578 LOGGERHEAD WAY'
#  '1416 LOCKHART WAY' '5413 BUENA VENTURA WAY' '37 WHITE BIRCH CT'
#  '405 MARLIN SPIKE WAY' '7320 6TH ST' '993 MANTON CT' '4487 PANORAMA DR'
#  '5651 OVERLEAF WAY' '2015 PROMONTORY POINT LN' '8 RIVER RAFT CT'
#  '2251 LAMPLIGHT LN' '106 FARHAM DR' '5405 NECTAR CIR' '5411 10TH AVE'
#  '3512 RAINSONG CIR' '1106 55TH ST' '411 ILLSLEY WAY' '796 BUTTERCUP CIR'
#  '1230 SANDRA CIR' '318 ANACAPA DR' '3975 SHINING STAR DR'
#  '1620 BASLER ST' '9688 NATURE TRAIL WAY' '9629 CEDAR OAK WAY'
#  '3429 FERNBROOK CT' '2121 HANNAH WAY' '10104 ANNIE ST' '1092 MAUGHAM CT'
#  '6306 CONEJO' '427 21ST ST' '1044 GALSTON DR' '4440 SYCAMORE AVE'
#  '9760 LAZULITE CT' '241 LANFRANCO CIR' '5559 NORTHBOROUGH DR'
#  '2109 HAMLET PL' '9970 STATE HIGHWAY 193' '2901 PINTAIL WAY'
#  '7756 TIGERWOODS DR' '5709 RIVER OAK WAY' '2981 WRINGER DR'
#  '4128 HILL ST' '1409 47TH ST' '3935 EL MONTE DR' '5840 WALERGA RD'
#  '923 FULTON AVE' '261 REDONDO AVE' '4030 BROADWAY' '3660 22ND AVE'
#  '3924 HIGH ST' '4734 14TH AVE' '5050 RHODE ISLAND DR Unit 4'
#  '4513 GREENHOLME DR' '3845 ELM ST' '3908 17TH AVE' '7109 CHANDLER DR'
#  '7541 SKELTON WAY' '9058 MONTOYA ST' '1016 CONGRESS AVE'
#  '540 MORRISON AVE' '5303 JERRETT WAY' '2820 DEL PASO BLVD'
#  '3715 TALLYHO DR Unit 78HIGH' '6013 ROWAN WAY' '2987 PONDEROSA LN'
#  '3732 LANKERSHIM WAY' '2216 DUNLAP DR' '3503 21ST AVE' '523 EXCHANGE ST'
#  '8101 PORT ROYALE WAY' '8020 WALERGA RD' '167 VALLEY OAK DR'
#  '7876 BURLINGTON WAY' '3726 JONKO AVE' '7342 GIGI PL' '2610 PHYLLIS AVE'
#  '4200 COMMERCE WAY Unit 711' '4621 COUNTRY SCENE WAY'
#  '5380 VILLAGE WOOD DR' '2621 EVERGREEN ST' '201 CARLO CT' '6743 21ST ST'
#  '3128 VIA GRANDE' '2847 BELGRADE WAY' '7741 MILLDALE CIR'
#  '9013 CASALS ST' '227 MAHAN CT Unit 1' '7349 FLETCHER FARM DR'
#  '7226 LARCHMONT DR' '4114 35TH AVE' '617 M ST' '7032 FAIR OAKS BLVD'
#  '2421 SANTINA WAY' '2368 CRAIG AVE' '2123 AMANDA WAY' '7620 DARLA WAY'
#  '8344 FIELDPOPPY CIR' '3624 20TH AVE' '2848 PROVO WAY'
#  '6045 EHRHARDT AVE' '1223 LAMBERTON CIR' '6000 BIRCHGLADE WAY'
#  '7204 THOMAS DR' '8363 LANGTREE WAY' '1675 VERNON ST Unit 8'
#  '6632 IBEX WOODS CT' '117 EVCAR WAY' '6485 LAGUNA MIRAGE LN'
#  '746 MOOSE CREEK WAY' '8306 CURLEW CT' '5217 ARGO WAY'
#  '7108 HEATHER TREE DR' '2956 DAVENPORT WAY' '10062 LINCOLN VILLAGE DR'
#  '332 PALIN AVE' '4649 FREEWAY CIR' '8593 DERLIN WAY' '9273 PREMIER WAY'
#  '8032 DUSENBERG CT' '7110 STELLA LN Unit 15' '1786 PIEDMONT WAY'
#  '1347 HIDALGO CIR' '212 CAPPUCINO WAY' '5938 WOODBRIAR WAY'
#  '3801 WILDROSE WAY' '508 SAMUEL WAY' '6128 CARL SANDBURG CIR'
#  '1 KENNELFORD CIR' '909 SINGINGWOOD RD' '6671 FOXWOOD CT'
#  '8165 AYN RAND CT' '9474 VILLAGE TREE DR' '7213 CALVIN DR'
#  '8167 DERBY PARK CT' '6344 LAGUNA MIRAGE LN' '2945 RED HAWK WAY'
#  '3228 I ST' '308 ATKINSON ST' '624 HOVEY WAY' '110 COPPER LEAF WAY'
#  '7535 ALMA VISTA WAY' '7423 WILSALL CT' '8629 VIA ALTA WAY'
#  '3318 DAVIDSON DR' '913 COBDEN CT' '4419 79TH ST' '3012 SPOONWOOD WAY'
#  '8728 CRYSTAL RIVER WAY' '4709 AMBER LN Unit 1' '4508 OLD DAIRY DR'
#  '312 RIVER ISLE WAY' '301 OLIVADI WAY' '5636 25TH ST'
#  '8721 SPRUCE RIDGE WAY' '7461 WINDBRIDGE DR' '8101 LEMON COVE CT'
#  '10949 SCOTSMAN WAY' '617 WILLOW CREEK DR' '3301 PARK DR Unit 1914'
#  '709 CIMMARON CT' '3305 RIO ROCA CT' '9080 BEDROCK CT'
#  '100 TOURMALINE CIR' '6411 RED BIRCH WAY' '4867 LAGUNA DR'
#  '3662 RIVER DR' '6943 WOLFGRAM WAY' '77 RINETTI WAY' '1316 I ST'
#  '2130 CATHERWOOD WAY' '8304 JUGLANS DR' '5308 MARBURY WAY'
#  '9182 LAKEMONT DR' '2231 COUNTRY VILLA CT' '361 MAHONIA CIR'
#  '3427 LA CADENA WAY' '955 BIG SUR CT' '11826 DIONYSUS WAY'
#  '5847 DEL CAMPO LN' '5635 FOXVIEW WAY' '10372 VIA CINTA CT'
#  '7744 SOUTHBREEZE DR' '2242 ABLE WAY' '1042 STARBROOK DR' '1219 G ST'
#  '6220 OPUS CT' '5419 HAVENHURST CIR' '220 OLD AIRPORT RD'
#  '4622 MEYER WAY' '4885 SUMMIT VIEW DR' '26 JEANROSS CT'
#  '4800 MAPLEPLAIN AVE' '10629 BASIE WAY' '8612 WILLOW GROVE WAY'
#  '62 DE FER CIR' '3253 ABOTO WAY' '251 CHANGO CIR' '8205 WEYBURN CT'
#  '8788 LA MARGARITA WAY' '5912 DEEPDALE WAY' '4712 PISMO BEACH DR'
#  '4741 PACIFIC PARK DR' '310 GROTH CIR' '6121 WILD FOX CT'
#  '29 COOL FOUNTAIN CT' '8909 BILLFISH WAY' '6232 GUS WAY'
#  '200 OAKWILDE ST' '200 ALLAIRE CIR' '5479 NICKMAN WAY'
#  '2103 BURBERRY WAY' '2450 SAN JOSE WAY' '2802 BLACK OAK DR'
#  '10112 LAMBEAU CT' '3622 CURTIS DR' '11817 OPAL RIDGE WAY'
#  '170 LAGOMARSINO WAY' '3361 ALDER CANYON WAY' '398 LINDLEY DR'
#  '169 BAURER CIR' '1315 KONDOS AVE' '4966 CHARTER RD'
#  '9516 LAGUNA LAKE WAY' '5201 BLOSSOM RANCH DR' '3027 PALMATE WAY'
#  '500 WINCHESTER CT' '6935 ELM TREE LN' '9605 GOLF COURSE LN'
#  '100 CHELSEA CT' '1500 ORANGE HILL LN' '2049 EMPIRE MINE CIR'
#  '9360 MAGOS RD' '104 CATLIN CT' '4734 GIBBONS DR' '4629 DORCHESTER LN'
#  '2400 COUNTRYSIDE DR' '12901 FURLONG DR' '6222 CALLE MONTALVO CIR'
#  '8208 WOODYARD WAY' '15 LOORZ CT' '5805 DOTMAR WAY' '2332 CAMBRIDGE ST'
#  '3812 BELDEN ST' '3348 40TH ST' '127 QUASAR CIR' '3812 CYPRESS ST'
#  '5821 64TH ST' '8248 CENTER PKWY' '1171 SONOMA AVE' '4250 ARDWELL WAY'
#  '3104 CLAY ST' '6063 LAND PARK DR' '4738 OAKHOLLOW DR' '1401 STERLING ST'
#  '3715 DIDCOT CIR' '2426 RASHAWN DR' '4800 WESTLAKE PKWY Unit 410'
#  '3409 VIRGO ST' '1110 PINEDALE AVE' '2361 LA LOMA DR' '1455 64TH AVE'
#  '7328 SPRINGMAN ST' '119 SAINT MARIE CIR' '12 COSTA BRASE CT'
#  '6813 SCOTER WAY' '6548 GRAYLOCK LN' '1630 GLIDDEN AVE'
#  '7825 DALEWOODS WAY' '4073 TRESLER AVE' '4288 DYMIC WAY'
#  '1158 SAN IGNACIO WAY' '4904 J PKWY' '2931 HOWE AVE' '5531 JANSEN DR'
#  '7836 ORCHARD WOODS CIR' '4055 DEERBROOK DR' '9937 BURLINE ST'
#  '6948 MIRADOR WAY' '4909 RUGER CT' '7204 KERSTEN ST' '3150 ROSEMONT DR'
#  '8200 STEINBECK WAY' '8198 STEVENSON AVE' '6824 OLIVE TREE WAY'
#  '3536 SUN MAIDEN WAY' '4517 OLYMPIAD WAY' '925 COBDEN CT'
#  '8225 SCOTTSDALE DR' '8758 LEMAS RD' '6121 ALPINESPRING WAY'
#  '5937 YORK GLEN WAY' '6417 SUNNYFIELD WAY' '4008 GREY LIVERY WAY'
#  '8920 ROSETTA CIR' '8300 LICHEN DR' '8884 AMBERJACK WAY'
#  '4480 VALLEY HI DR' '2250 FOREBAY RD' '3529 FABERGE WAY'
#  '1792 DAWNELLE WAY' '7800 TABARE CT' '8531 HERMITAGE WAY'
#  '2421 BERRYWOOD DR' '1005 MORENO WAY' '1675 VERNON ST Unit 24'
#  '24 WINDCHIME CT' '540 HARLING CT' '1207 CRESCENDO DR' '7577 EDDYLEE WAY'
#  '8369 FOPPIANO WAY' '8817 SAWTELLE WAY' '1910 BONAVISTA WAY' '8 TIDE CT'
#  '8952 ROCKY CREEK CT' '435 EXCHANGE ST' '10105 MONTE VALLO CT'
#  '3930 ANNABELLE AVE' '4854 TANGERINE AVE' '2909 SHAWN WAY'
#  '4290 BLACKFORD WAY' '7015 WOODSIDE DR' '6019 CHESHIRE WAY'
#  '2561 VERNA WAY' '3522 22ND AVE' '2880 CANDIDO DR' '6908 PIN OAK CT'
#  '5733 ANGELINA AVE' '7849 BONNY DOWNS WAY' '8716 LONGSPUR WAY'
#  '6320 EL DORADO ST' '2328 DOROTHY JUNE WAY' '1986 DANVERS WAY'
#  '7901 GAZELLE TRAIL WAY' '6080 BRIDGECROSS DR' '20 GROTH CIR'
#  '1900 DANBROOK DR' '8442 KEUSMAN ST' '9552 SUNLIGHT LN'
#  '1407 TIFFANY CIR' '636 CRESTVIEW DR' '1528 HESKET WAY' '2327 32ND ST'
#  '1833 2ND AVE' '7252 CARRIAGE DR' '9815 PASO FINO WAY' '5532 ENGLE RD'
#  '1139 CLINTON RD' '9176 SAGE GLEN WAY' '9264 BOULDER RIVER WAY'
#  '320 GROTH CIR' '137 GUNNISON AVE' '8209 RIVALLO WAY'
#  '8637 PERIWINKLE CIR' '3425 MEADOW WAY' '107 JARVIS CIR' '2319 THORES ST'
#  '8935 MOUNTAIN HOME CT' '2566 SERENATA WAY' '4085 COUNTRY DR'
#  '9297 TROUT WAY' '7 ARCHIBALD CT' '11130 EEL RIVER CT' '8323 REDBANK WAY'
#  '16 BRONCO CREEK CT' '8316 NORTHAM DR' '4240 WINJE DR' '5118 ROBANDER ST'
#  '5976 KYLENCH CT' '9247 DELAIR WAY' '9054 DESCENDANT DR'
#  '3450 WHITNOR CT' '9355 MATADOR WAY' '8671 SUMMER SUN WAY'
#  '1890 GENEVA PL' '1813 AVENIDA MARTINA' '191 BARNHART CIR'
#  '6221 GREEN TOP WAY' '2298 PRIMROSE LN' '5635 LOS PUEBLOS WAY'
#  '10165 LOFTON WAY' '9949 NESTLING CIR' '2915 HOLDREGE WAY'
#  '2678 BRIARTON DR' '294 SPARROW DR' '2987 DIORITE WAY' '6326 APPIAN WAY'
#  '6905 COBALT WAY' '8986 HAFLINGER WAY' '2916 BABSON DR'
#  '10133 NEBBIOLO CT' '1103 COMMONS DR' '4636 TEAL BAY CT'
#  '1524 YOUNGS AVE' '8463 TERRACOTTA CT' '5747 KING RD' '9204 TROUT WAY'
#  '1828 2ND AVE' '1113 COMMONS DR' '2341 BIG STRIKE TRL'
#  '9452 RED SPRUCE WAY' '5776 TERRACE DR' '5908 MCLEAN DR'
#  '8215 PEREGRINE WAY' '2949 PANAMA AVE' '1356 HARTLEY WAY'
#  '633 HANISCH DR' '63 ANGEL ISLAND CIR' '1571 WILD OAK LN'
#  '5601 SPINDRIFT LN' '652 FIFTEEN MILE DR' '7921 DOE TRAIL WAY'
#  '4204 LUSK DR' '5608 ROSEDALE WAY' '3372 BERETANIA WAY'
#  '2422 STEFANIE DR' '1214 DAWNWOOD DR' '3349 CORVINA DR'
#  '10254 JULIANA WAY' '149 OPUS CIR' '580 REGENCY PARK CIR' '5544 CAMAS CT'
#  '5102 ARCHCREST WAY' '5725 BALFOR RD' '4821 HUTSON WAY' '4509 WINJE DR'
#  '6709 ROSE BRIDGE DR' '281 SPYGLASS HL' '7709 RIVER VILLAGE DR'
#  '506 BEDFORD CT' '9048 PINTO CANYON WAY' '14004 WALNUT AVE'
#  '6905 FRANKFORT CT' '3621 WINTUN DR' '1975 SIDESADDLE WAY'
#  '9677 PILLITERI CT' '556 PLATT CIR' '1124 PERKINS WAY' '4748 SALEM WAY'
#  '1484 RADCLIFFE WAY' '51 AIKEN WAY' '700 HUNTER PL' '1240 FAY CIR'
#  '1113 SANDWICK WAY' '3108 DELWOOD WAY' '3212 CORNICHE LN'
#  '8217 PLUMERIA AVE' '3863 LAS PASAS WAY' '1165 37TH ST'
#  '203 CASCADE FALLS DR' '9880 IZILDA CT' '620 KESWICK CT' '8432 BRIGGS DR'
#  '9401 BARREL RACER CT' '14151 INDIO DR' '7401 TOULON LN'
#  '9127 NEWHALL DR Unit 34' '5937 BAMFORD DR' '5672 HILLSDALE BLVD'
#  '3920 39TH ST' '701 JESSIE AVE' '83 ARCADE BLVD' '601 REGGINALD WAY'
#  '550 DEL VERDE CIR' '4113 DAYSTAR CT' '7374 TISDALE WAY'
#  '3348 RIO LINDA BLVD' '3935 LIMESTONE WAY' '6208 GRATTAN WAY'
#  '739 E WOODSIDE LN Unit E' '4225 46TH AVE' '1434 BELL AVE'
#  '5628 GEORGIA DR' '7629 BETH ST' '2277 BABETTE WAY'
#  '6561 WEATHERFORD WAY' '5136 CABOT CIR' '7730 ROBINETTE RD'
#  '87 LACAM CIR' '1691 NOGALES ST' '3118 42ND ST' '7517 50TH AVE'
#  '4071 EVALITA WAY' '7928 36TH AVE' '6631 DEMARET DR' '7043 9TH AVE'
#  '97 KENNELFORD CIR' '2636 TRONERO WAY' '3604 KODIAK WAY'
#  '2149 COTTAGE WAY' '8632 PRAIRIEWOODS DR' '612 STONE BLVD'
#  '4180 12TH AVE' '8025 ARROYO VISTA DR' '5754 WALERGA RD Unit 4'
#  '8 LA ROCAS CT' '8636 LONGSPUR WAY' '1941 EXPEDITION WAY'
#  '4351 TURNBRIDGE DR' '6513 HOLIDAY WAY' '8321 MISTLETOE WAY'
#  '5920 VALLEY GLEN WAY' '2601 SAN FERNANDO WAY' '8008 SAINT HELENA CT'
#  '6517 DONEGAL DR' '1001 RIO NORTE WAY' '604 P ST' '7351 GIGI PL'
#  '7740 DIXIE LOU ST' '7342 DAVE ST' '7687 HOWERTON DR' '26 KAMSON CT'
#  '7045 PEEVEY CT' '8916 GABLES MILL PL' '1140 EDMONTON DR'
#  '8879 APPLE PEAR CT' '9 WIND CT' '8570 SHERATON DR' '1080 RIO NORTE WAY'
#  '5501 VALLETTA WAY' '5624 MEMORY LN' '6622 WILLOWLEAF DR' '27 MEGAN CT'
#  '6601 WOODMORE OAKS DR' '1973 DANVERS WAY' '8001 ARROYO VISTA DR'
#  '7409 VOYAGER WAY' '815 CROSSWIND DR' '5509 LAGUNA CREST WAY'
#  '8424 MERRY HILL WAY' '5954 BRIDGECROSS DR' '8789 SEQUOIA WOOD CT'
#  '6600 SILVERTHORNE CIR' '2221 2ND AVE' '3230 SMATHERS WAY'
#  '5209 LAGUNA CREST WAY' '416 LEITCH AVE' '2100 BEATTY WAY'
#  '6920 GILLINGHAM WAY' '82 WILDFLOWER DR' '8652 BANTON CIR'
#  '8428 MISTY PASS WAY' '7958 ROSEVIEW WAY' '9020 LUKEN CT'
#  '7809 VALLECITOS WAY' '8445 OLD AUBURN RD' '10085 ATKINS DR'
#  '9185 CERROLINDA CIR' '5429 HESPER WAY' '1178 WARMWOOD CT'
#  '4900 ELUDE CT' '3528 SAINT GEORGE DR' '7381 WASHBURN WAY'
#  '7540 HICKORY AVE' '5024 CHAMBERLIN CIR' '2400 INVERNESS DR'
#  '5 BISHOPGATE CT' '5601 REXLEIGH DR' '1909 YARNELL WAY'
#  '9169 GARLINGTON CT' '6932 RUSKUT WAY' '7933 DAFFODIL WAY'
#  '8304 RED FOX WAY' '3882 YELLOWSTONE LN']
# ['SACRAMENTO' 'RANCHO CORDOVA' 'RIO LINDA' 'CITRUS HEIGHTS'
#  'NORTH HIGHLANDS' 'ANTELOPE' 'ELK GROVE' 'ELVERTA' 'GALT' 'CARMICHAEL'
#  'ORANGEVALE' 'FOLSOM' 'MATHER' 'POLLOCK PINES' 'GOLD RIVER'
#  'RANCHO MURIETA' 'WILTON' 'GREENWOOD' 'FAIR OAKS' 'PLACERVILLE'
#  'MEADOW VISTA' 'ROSEVILLE' 'LINCOLN' 'CAMERON PARK' 'ROCKLIN' 'LOOMIS'
#  'AUBURN' 'EL DORADO HILLS' 'EL DORADO' 'PENRYN' 'GRANITE BAY'
#  'DIAMOND SPRINGS' 'COOL' 'WALNUT GROVE' 'SLOUGHHOUSE' 'WEST SACRAMENTO']
# ['Residential' 'Condo' 'Multi-Family']

# %%
house_res = house[house['type'] == 'Residential']
house_con = house[house['type'] == 'Condo']
house_mult = house[house['type'] == 'Multi-Family']


sns.distplot( house_res["price"] , color="skyblue", label="Residential")
sns.distplot( house_con["price"] , color="red", label="Condo")
sns.distplot( house_mult["price"] , color="orange", label="Multi_Family")
sns.distplot( house['price'], color ="black", label = 'Total')
plt.title('Housing Price Distribution by Type')
plt.legend()

# %%
house['type'].value_counts().plot(kind='bar')

# %% [markdown]
# ### 2. Predict Price

# %% [markdown]
# We are going to predict `price` from available information.

# %% [markdown]
# #### 2.1 What is the Target Variable? Why?

# %%
# ANSWER
print ('price')
# Out:
# price

# %% [markdown]
# #### 2.2 List all possible variables which might be Predictor variable.

# %% [markdown]
# -Sqft
# -beds
# -baths
# -zip

# %% [markdown]
# #### 2.2 Find correlation between variables
#
# Find correlation between variables. Which is the best predictor? Why? State your reason.
#
# -Choosing sq_ft as it has the highest correlation among all other variables relating to price

# %%
# ANSWER
sns.heatmap(house.corr(), annot=True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# #### 2.3 What is the simplest way to predict price
#
# So we have information for 985 houses. What is the easiest way to predict price of a house?

# %%
# ANSWER
sns.scatterplot(x='sq__ft', y='price', hue='type',
                     data=house)

# %% [markdown]
# #### 2. 4 Find Resudals
#
# Find difference between actual value and predicted value. Use absolute value.

# %%
# ANSWER

# %% [markdown]
# #### 2.5  Predict Using Linear Regression
#
# [Simple Linear Regression](https://en.wikipedia.org/wiki/Simple_linear_regression#Fitting_the_regression_line)
#
# ### $$\hat{y} = \beta_0 + \beta_1 x$$
#
# > ### $$ \beta_1 = \frac{\sum_{i=1}^n (y_i - \bar{y} ) (x_i - \bar{x} )}{\sum_{i=1}^n (x_i - \bar{x})^2} $$
#
# and
#
# > ### $$ \beta_0 = \bar{y} - \beta_1\bar{x} $$
#
# Given variables:
# - $\bar{y}$ : the sample mean of observed values $Y$
# - $\bar{x}$ : the sample mean of observed values $X$

# %% [markdown]
# ##### 2.5 Define X, Y
#
# - X = Predictor Variable
# - Y = Target Variable

# %%
# ANSWER

# %% [markdown]
# ##### 2.5.A Calculate beta_1
#
#  ### $$ \beta_1 = \frac{\sum_{i=1}^n (y_i - \bar{y} ) (x_i - \bar{x} )}{\sum_{i=1}^n (x_i - \bar{x})^2} $$

# %%
# ANSWER

# %% [markdown]
# ##### 2.5.B Calculate beta_0

# %% [markdown]
# ### $$ \beta_0 = \bar{y} - \beta_1\bar{x} $$

# %%
# ANSWER
beta_0 = house['price'].mean()

# %% [markdown]
# ##### 2.4.C Find Yhat (Predicted Value Using Beta 0 and Beta 1)

# %% [markdown]
# ### $$\hat{y} = \beta_0 + \beta_1 x$$

# %%
# ANSWER
X = house['sq__ft'].values.reshape(-1, 1)  # values converts it into a numpy array
Y = house['price'].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions

# %%
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.show()

# %% [markdown]
# ##### 2.5.D Find Resudals

# %% [markdown]
# ### $$ \text{residual}_i = y_i - \hat{y}_i$$

# %%
# ANSWER
res = abs(Y - Y_pred)
res
# Out:
# array([[7.56696167e+04],
#        [1.08126274e+05],
#        [6.10029573e+04],
#        [6.75880805e+04],
#        [4.81081738e+04],
#        [8.07825319e+04],
#        [7.75546352e+04],
#        [8.65884387e+04],
#        [5.31343478e+04],
#        [7.47717276e+04],
#        [4.37234203e+04],
#        [8.53646852e+04],
#        [3.24221938e+04],
#        [5.04294503e+04],
#        [4.94318833e+04],
#        [6.15061298e+04],
#        [2.26303486e+04],
#        [1.35077408e+04],
#        [1.61620720e+04],
#        [7.83741898e+04],
#        [4.82026660e+04],
#        [7.39413447e+04],
#        [6.24790773e+04],
#        [1.06582229e+05],
#        [1.80306884e+04],
#        [3.98061714e+04],
#        [2.35131105e+04],
#        [4.13278825e+04],
#        [7.18093855e+04],
#        [5.44808092e+04],
#        [2.73105635e+04],
#        [3.99050265e+04],
#        [6.65093855e+04],
#        [3.12022330e+04],
#        [1.93105635e+04],
#        [6.15176120e+04],
#        [1.83868725e+04],
#        [6.57793023e+04],
#        [2.41157276e+04],
#        [2.46248363e+04],
#        [4.14929325e+04],
#        [2.73469333e+04],
#        [5.54324380e+03],
#        [4.38570526e+02],
#        [6.74291982e+04],
#        [6.45309895e+03],
#        [6.30526828e+04],
#        [1.08651865e+05],
#        [7.12121358e+04],
#        [4.71553847e+04],
#        [8.96782004e+03],
#        [5.63048477e+04],
#        [3.91523539e+04],
#        [7.05186920e+04],
#        [1.12170583e+02],
#        [2.75050141e+04],
#        [9.39262675e+04],
#        [4.03564374e+03],
#        [7.41197348e+03],
#        [7.93993507e+04],
#        [3.67334817e+02],
#        [1.10447362e+04],
#        [4.77326620e+04],
#        [2.66648177e+04],
#        [1.90180450e+04],
#        [1.57926318e+03],
#        [3.48039817e+04],
#        [5.93748872e+03],
#        [1.05928678e+05],
#        [9.26529400e+03],
#        [4.54569085e+04],
#        [5.81046396e+04],
#        [5.25867346e+04],
#        [1.14127452e+04],
#        [1.64408477e+04],
#        [9.05614661e+03],
#        [2.28740575e+04],
#        [7.46150494e+04],
#        [4.67347634e+03],
#        [1.61963988e+04],
#        [4.33327478e+04],
#        [4.48879126e+04],
#        [2.44758934e+04],
#        [7.33844816e+04],
#        [5.44887405e+04],
#        [6.05280975e+04],
#        [5.84158946e+04],
#        [5.48896445e+04],
#        [9.47919719e+04],
#        [9.83355825e+04],
#        [5.63818510e+04],
#        [2.05699358e+04],
#        [5.38863048e+04],
#        [6.78461882e+03],
#        [1.65515048e+04],
#        [1.21564632e+05],
#        [3.68307602e+04],
#        [1.02332983e+05],
#        [2.54274004e+04],
#        [6.19906145e+04],
#        [1.19445292e+05],
#        [5.34741403e+04],
#        [6.38123264e+04],
#        [8.99193972e+04],
#        [1.26000042e+05],
#        [2.00092584e+05],
#        [2.65573048e+03],
#        [7.64990818e+03],
#        [2.82623504e+04],
#        [1.20819602e+05],
#        [1.03147189e+04],
#        [4.55005516e+04],
#        [3.70153812e+04],
#        [7.84603064e+04],
#        [7.67797966e+04],
#        [8.33550161e+03],
#        [1.10610578e+04],
#        [1.50471801e+05],
#        [5.84850106e+04],
#        [9.23235036e+04],
#        [3.56755601e+04],
#        [1.07797565e+04],
#        [4.04413427e+04],
#        [9.04844736e+04],
#        [7.12688358e+04],
#        [7.49891031e+04],
#        [8.12997941e+04],
#        [2.05250845e+03],
#        [7.75825792e+04],
#        [5.13955977e+04],
#        [9.95647694e+04],
#        [9.45367025e+04],
#        [1.28374196e+05],
#        [1.57062142e+05],
#        [6.64853480e+04],
#        [8.42324504e+03],
#        [7.45896741e+04],
#        [1.27845135e+05],
#        [3.50788326e+04],
#        [5.28682332e+04],
#        [9.33326664e+04],
#        [8.96996564e+04],
#        [2.83766520e+04],
#        [4.05299309e+04],
#        [2.00506376e+05],
#        [3.38661035e+05],
#        [6.07577408e+04],
#        [9.78235527e+04],
#        [6.43924827e+04],
#        [5.23838232e+04],
#        [4.52221329e+04],
#        [8.38166252e+04],
#        [1.05995530e+05],
#        [1.07625077e+05],
#        [4.88985443e+04],
#        [5.39106676e+04],
#        [1.29176907e+04],
#        [8.49747476e+04],
#        [2.26169372e+04],
#        [1.36941321e+05],
#        [2.06169372e+04],
#        [5.87284395e+04],
#        [4.93105635e+04],
#        [5.08131614e+04],
#        [3.64949765e+04],
#        [4.75903362e+04],
#        [3.84629449e+04],
#        [4.54509341e+04],
#        [1.64028740e+04],
#        [4.54530989e+04],
#        [3.94444395e+04],
#        [2.10428116e+04],
#        [1.54167292e+04],
#        [4.68477992e+04],
#        [5.29842730e+04],
#        [2.54444395e+04],
#        [4.87347060e+04],
#        [1.21758216e+04],
#        [3.72208509e+04],
#        [2.43830628e+04],
#        [6.65241066e+04],
#        [3.39678200e+04],
#        [3.23417376e+04],
#        [4.69963963e+04],
#        [2.10774495e+04],
#        [5.10059217e+04],
#        [4.42442314e+04],
#        [4.17841947e+03],
#        [1.24496352e+04],
#        [2.43640119e+04],
#        [1.48287484e+04],
#        [1.43816622e+04],
#        [1.33078925e+04],
#        [3.37926128e+04],
#        [3.95119833e+04],
#        [4.23971582e+04],
#        [6.33654193e+03],
#        [6.44473831e+04],
#        [7.18373207e+04],
#        [9.60948952e+03],
#        [2.36963640e+04],
#        [6.46821250e+04],
#        [5.92004139e+04],
#        [7.47315880e+04],
#        [3.99222707e+04],
#        [1.85469011e+04],
#        [2.14182208e+04],
#        [1.77852108e+04],
#        [4.63719981e+03],
#        [1.33853148e+04],
#        [5.04750934e+04],
#        [6.97584324e+04],
#        [8.62578463e+04],
#        [6.25841368e+04],
#        [1.28022498e+04],
#        [1.98792532e+04],
#        [2.18759442e+04],
#        [4.20987341e+03],
#        [2.44647020e+04],
#        [1.13472131e+04],
#        [3.18309499e+03],
#        [1.47600483e+04],
#        [4.75261183e+04],
#        [3.51296861e+04],
#        [3.57513151e+03],
#        [1.85951142e+04],
#        [6.90590902e+04],
#        [4.43848818e+04],
#        [2.65889867e+04],
#        [9.71249022e+04],
#        [5.58896445e+04],
#        [7.25347778e+04],
#        [3.74741615e+04],
#        [3.22150691e+04],
#        [2.76986161e+04],
#        [3.52330086e+04],
#        [4.42014100e+04],
#        [3.00690699e+04],
#        [3.45751315e+04],
#        [7.73621083e+04],
#        [1.34066177e+04],
#        [1.44001018e+04],
#        [4.80829250e+04],
#        [3.78065137e+04],
#        [1.26557305e+04],
#        [6.25005516e+04],
#        [7.42384604e+04],
#        [9.80519348e+03],
#        [8.14776253e+04],
#        [7.25767910e+04],
#        [8.83610683e+04],
#        [8.98779034e+04],
#        [1.09011397e+05],
#        [1.90850686e+04],
#        [1.03376655e+05],
#        [3.11258766e+04],
#        [2.67355060e+04],
#        [1.34760130e+04],
#        [1.18350677e+05],
#        [1.42267026e+05],
#        [2.16430871e+04],
#        [2.36297680e+05],
#        [2.93113635e+04],
#        [1.70049499e+05],
#        [1.09069070e+05],
#        [4.44469714e+04],
#        [3.24175292e+04],
#        [9.56414636e+04],
#        [9.36230414e+04],
#        [1.16615442e+05],
#        [8.45693072e+04],
#        [5.34163804e+04],
#        [1.16352929e+05],
#        [4.53499854e+04],
#        [3.47256564e+04],
#        [7.92715930e+04],
#        [4.90165935e+03],
#        [2.58644407e+05],
#        [9.66056140e+04],
#        [1.70841672e+05],
#        [7.00748487e+04],
#        [9.42896088e+03],
#        [4.44258187e+04],
#        [2.53693420e+05],
#        [2.13246763e+05],
#        [8.03747520e+04],
#        [4.34268832e+04],
#        [2.73558333e+05],
#        [1.02609490e+05],
#        [2.93423245e+05],
#        [3.57751613e+05],
#        [6.05437792e+05],
#        [9.53924827e+04],
#        [4.28154134e+04],
#        [9.01706259e+04],
#        [4.61705051e+04],
#        [8.19123995e+04],
#        [6.48829573e+04],
#        [6.66411838e+04],
#        [6.66411838e+04],
#        [6.89106676e+04],
#        [4.70257408e+04],
#        [1.02731242e+05],
#        [6.87486568e+04],
#        [7.20549349e+04],
#        [6.69297184e+04],
#        [3.97577408e+04],
#        [5.41593686e+04],
#        [7.06948725e+04],
#        [5.34193270e+04],
#        [1.06014581e+05],
#        [8.47093804e+03],
#        [4.04028740e+04],
#        [6.77030989e+04],
#        [8.43737776e+04],
#        [4.41801514e+04],
#        [9.75241066e+04],
#        [3.71697600e+04],
#        [1.30042770e+04],
#        [1.98916167e+04],
#        [5.29487692e+04],
#        [6.11147892e+04],
#        [6.20969333e+04],
#        [1.60017525e+05],
#        [1.08846892e+04],
#        [3.01680281e+04],
#        [8.11483547e+04],
#        [2.15306884e+04],
#        [4.36369140e+03],
#        [4.34444395e+04],
#        [4.54496352e+04],
#        [2.69210589e+04],
#        [7.86885504e+04],
#        [7.30397568e+04],
#        [2.79774078e+03],
#        [8.79493477e+02],
#        [1.01429198e+05],
#        [5.15973663e+04],
#        [3.97272122e+04],
#        [1.05326496e+05],
#        [4.66051598e+04],
#        [6.75171790e+04],
#        [5.21920666e+04],
#        [2.54530989e+04],
#        [8.23048477e+04],
#        [5.67902306e+04],
#        [7.00388277e+04],
#        [8.63169709e+04],
#        [8.50734655e+04],
#        [4.63222206e+04],
#        [4.62572206e+04],
#        [4.13781074e+04],
#        [1.64600265e+04],
#        [5.20249725e+04],
#        [5.82504432e+03],
#        [1.17121914e+04],
#        [1.42165211e+04],
#        [4.45136705e+03],
#        [9.48769215e+02],
#        [2.31947368e+04],
#        [2.31947368e+04],
#        [7.68943647e+03],
#        [5.33654193e+03],
#        [1.00250639e+05],
#        [5.05396936e+04],
#        [6.97128383e+03],
#        [7.54690105e+03],
#        [3.00215087e+04],
#        [3.18997560e+04],
#        [5.53152390e+04],
#        [2.65728795e+04],
#        [1.38649735e+04],
#        [1.67895405e+04],
#        [7.62854034e+03],
#        [3.92334466e+03],
#        [5.00418980e+03],
#        [2.10074463e+04],
#        [4.14459311e+04],
#        [2.68867054e+04],
#        [5.63380335e+04],
#        [4.43429493e+04],
#        [6.51306180e+04],
#        [4.25951142e+04],
#        [2.42670259e+04],
#        [5.09408969e+04],
#        [4.42456329e+04],
#        [4.76124331e+04],
#        [5.80054015e+04],
#        [5.99233124e+04],
#        [3.28412175e+04],
#        [8.04243483e+04],
#        [7.08337038e+04],
#        [2.69621042e+04],
#        [2.86117233e+03],
#        [6.92144773e+04],
#        [5.77729346e+02],
#        [4.63539843e+04],
#        [3.44906804e+04],
#        [3.67575005e+04],
#        [1.05647702e+05],
#        [5.26992359e+04],
#        [2.96166969e+04],
#        [4.57687578e+04],
#        [7.09513232e+04],
#        [5.51573964e+04],
#        [3.85027378e+04],
#        [3.76297521e+04],
#        [9.24763051e+04],
#        [2.71784396e+04],
#        [2.32389852e+03],
#        [1.64888769e+04],
#        [1.22584757e+05],
#        [1.76037737e+04],
#        [1.75376547e+05],
#        [2.01098353e+04],
#        [5.12566345e+04],
#        [9.06153768e+04],
#        [6.97687778e+04],
#        [6.92634789e+04],
#        [7.44002416e+04],
#        [4.24810891e+04],
#        [2.48536161e+04],
#        [5.18480449e+03],
#        [1.19161431e+04],
#        [7.26426753e+04],
#        [4.15564924e+04],
#        [7.62282451e+03],
#        [5.89795822e+03],
#        [1.03672529e+05],
#        [2.12935245e+04],
#        [5.73489450e+04],
#        [9.68753436e+04],
#        [6.13075637e+04],
#        [7.15326749e+04],
#        [8.37197981e+03],
#        [1.38092787e+04],
#        [8.65166245e+04],
#        [6.57124712e+04],
#        [1.34581539e+05],
#        [5.95768634e+04],
#        [5.54377918e+04],
#        [1.09858362e+05],
#        [1.70779573e+03],
#        [7.50154404e+04],
#        [1.10878191e+05],
#        [3.48232371e+04],
#        [4.30136493e+04],
#        [3.38719868e+03],
#        [1.08375584e+05],
#        [1.09864120e+05],
#        [1.44461410e+05],
#        [3.96851162e+03],
#        [9.06271895e+02],
#        [9.06332147e+04],
#        [4.98929434e+03],
#        [3.99478373e+04],
#        [8.88935252e+04],
#        [2.84394152e+04],
#        [1.22458689e+05],
#        [5.46054560e+04],
#        [9.60613196e+04],
#        [1.06704690e+05],
#        [1.24050019e+05],
#        [1.39943853e+05],
#        [2.00159128e+05],
#        [1.52559544e+05],
#        [4.59459267e+04],
#        [1.57296988e+05],
#        [1.17143991e+05],
#        [1.68178813e+05],
#        [1.49994598e+05],
#        [1.73402288e+05],
#        [1.88970287e+05],
#        [1.64105960e+05],
#        [1.19017176e+05],
#        [1.09879836e+05],
#        [1.55047075e+05],
#        [6.21277828e+04],
#        [1.40872500e+05],
#        [2.31251959e+05],
#        [3.11191604e+05],
#        [1.17506896e+05],
#        [8.04474895e+04],
#        [2.72713512e+05],
#        [2.17802620e+05],
#        [2.83362421e+05],
#        [3.93273981e+05],
#        [1.87128315e+05],
#        [2.70244860e+05],
#        [1.46213057e+05],
#        [7.97200497e+04],
#        [8.04063378e+04],
#        [9.44340481e+04],
#        [7.84063378e+04],
#        [1.00444439e+05],
#        [8.76749557e+04],
#        [7.19054719e+04],
#        [6.30220289e+04],
#        [6.66567708e+04],
#        [7.18045019e+04],
#        [7.09463879e+04],
#        [3.82507508e+04],
#        [2.61338232e+04],
#        [8.69903347e+04],
#        [2.36359881e+04],
#        [5.44409757e+04],
#        [2.92828532e+04],
#        [2.11437816e+04],
#        [7.99963963e+04],
#        [9.11458801e+04],
#        [5.38270165e+04],
#        [5.45887068e+04],
#        [5.34626244e+04],
#        [7.51259425e+04],
#        [5.88495311e+04],
#        [4.73296144e+04],
#        [6.50730049e+04],
#        [6.21068917e+04],
#        [4.04530989e+04],
#        [3.84526660e+04],
#        [1.29148794e+05],
#        [5.02234071e+04],
#        [6.75137152e+04],
#        [4.84842730e+04],
#        [1.79401097e+04],
#        [2.69556968e+04],
#        [6.37780033e+04],
#        [1.69470373e+04],
#        [8.30630742e+04],
#        [4.58153892e+03],
#        [9.01835705e+03],
#        [5.28777768e+04],
#        [4.22546228e+04],
#        [1.80221438e+05],
#        [4.67658801e+04],
#        [8.29560426e+04],
#        [5.43066836e+04],
#        [1.09574287e+04],
#        [5.91709717e+04],
#        [4.17658801e+04],
#        [1.81860773e+04],
#        [7.65812591e+04],
#        [6.00526828e+04],
#        [7.04469501e+04],
#        [9.69160134e+03],
#        [1.67558133e+03],
#        [1.30553462e+05],
#        [6.38178369e+04],
#        [2.04963963e+04],
#        [4.37541788e+03],
#        [4.63923282e+02],
#        [2.34520140e+03],
#        [6.34525788e+04],
#        [4.91389104e+03],
#        [2.67658801e+04],
#        [2.78521077e+03],
#        [4.86804971e+04],
#        [1.49277462e+04],
#        [6.92568153e+04],
#        [2.49475087e+04],
#        [1.48790351e+04],
#        [1.39527878e+04],
#        [4.83152390e+04],
#        [8.16312818e+03],
#        [3.88778590e+02],
#        [2.43051275e+04],
#        [3.78022498e+04],
#        [6.01170427e+04],
#        [1.25106844e+04],
#        [1.90249725e+04],
#        [2.61631782e+04],
#        [3.28022498e+04],
#        [5.25864547e+04],
#        [1.96545187e+04],
#        [2.37904065e+04],
#        [2.85703856e+04],
#        [2.65417054e+04],
#        [4.90789411e+04],
#        [1.14041852e+05],
#        [1.04058177e+04],
#        [4.45642200e+04],
#        [3.39220982e+03],
#        [4.86003099e+04],
#        [6.70144324e+04],
#        [3.85469011e+04],
#        [2.55226545e+04],
#        [5.75203432e+04],
#        [1.08089831e+05],
#        [1.56218926e+04],
#        [1.24914805e+04],
#        [2.30409334e+04],
#        [6.29965201e+03],
#        [5.01729835e+04],
#        [6.05659519e+04],
#        [1.21071715e+04],
#        [3.18913764e+04],
#        [1.44880226e+04],
#        [3.13451142e+04],
#        [2.42497070e+04],
#        [8.96985948e+04],
#        [1.43524088e+04],
#        [5.45166588e+04],
#        [6.76708845e+04],
#        [6.18025297e+04],
#        [1.68178626e+04],
#        [8.04494608e+04],
#        [6.83068594e+04],
#        [6.10426372e+04],
#        [2.32563041e+03],
#        [3.00002059e+04],
#        [8.65980578e+04],
#        [3.49143807e+04],
#        [3.57349859e+04],
#        [1.07729285e+04],
#        [2.16167629e+04],
#        [6.16910051e+04],
#        [9.70027165e+04],
#        [6.92653446e+03],
#        [4.76184288e+04],
#        [1.89967421e+04],
#        [1.49351939e+04],
#        [9.10637152e+03],
#        [4.17280583e+04],
#        [4.31002440e+04],
#        [3.44603064e+04],
#        [3.62133372e+04],
#        [9.91995817e+04],
#        [8.00304481e+04],
#        [2.68134412e+04],
#        [6.52230876e+03],
#        [4.34659766e+04],
#        [5.15803272e+04],
#        [6.65005516e+04],
#        [3.96821631e+04],
#        [2.94399354e+04],
#        [3.67042235e+04],
#        [6.91019759e+04],
#        [5.16968842e+04],
#        [2.22623504e+04],
#        [4.05387617e+04],
#        [3.66438995e+03],
#        [4.44170090e+04],
#        [1.06782451e+04],
#        [9.07361815e+04],
#        [4.84647926e+04],
#        [9.85018718e+04],
#        [1.96102895e+04],
#        [1.25541705e+05],
#        [6.65630083e+04],
#        [8.73489450e+04],
#        [5.01387573e+04],
#        [7.28899666e+04],
#        [5.17717673e+04],
#        [9.93610683e+04],
#        [9.17142031e+04],
#        [1.13627088e+05],
#        [5.43996901e+04],
#        [9.71280652e+03],
#        [2.58675416e+04],
#        [3.38555268e+04],
#        [7.81049760e+03],
#        [1.07639103e+05],
#        [1.14494944e+05],
#        [1.30013129e+05],
#        [7.91018674e+04],
#        [5.83806393e+04],
#        [1.04324245e+05],
#        [3.57077957e+04],
#        [1.00483868e+04],
#        [1.90505392e+04],
#        [2.68104976e+04],
#        [1.02439524e+05],
#        [1.37758597e+04],
#        [1.01497982e+04],
#        [4.14584660e+04],
#        [5.08514344e+04],
#        [4.78191571e+04],
#        [5.68347441e+04],
#        [9.60257725e+04],
#        [4.24175292e+04],
#        [1.45694800e+04],
#        [1.33540494e+05],
#        [1.64420883e+05],
#        [1.48778081e+05],
#        [1.08720785e+05],
#        [6.79196693e+03],
#        [9.44383119e+04],
#        [2.20007068e+05],
#        [9.25340862e+04],
#        [1.05000209e+05],
#        [2.07841152e+05],
#        [6.18110178e+04],
#        [6.11780077e+04],
#        [7.45840307e+03],
#        [1.62719919e+05],
#        [1.26899344e+05],
#        [9.74774539e+04],
#        [3.45997542e+05],
#        [3.88018325e+05],
#        [1.40465331e+05],
#        [8.47730781e+04],
#        [2.74779324e+05],
#        [1.31639560e+05],
#        [3.03626825e+05],
#        [7.57221019e+05],
#        [1.62587962e+05],
#        [4.67179072e+04],
#        [7.89002762e+04],
#        [8.50376159e+04],
#        [6.98316784e+04],
#        [8.68045019e+04],
#        [9.52113254e+04],
#        [8.14470373e+04],
#        [5.79175951e+04],
#        [7.92322122e+04],
#        [6.76896768e+04],
#        [6.26857800e+04],
#        [9.57537568e+04],
#        [5.68131614e+04],
#        [7.94227778e+03],
#        [6.65869749e+04],
#        [4.59279865e+04],
#        [7.41016960e+04],
#        [7.41060257e+04],
#        [6.07869749e+04],
#        [4.06792854e+04],
#        [9.17771374e+04],
#        [6.71103555e+04],
#        [5.52928200e+04],
#        [9.99465180e+04],
#        [4.00132538e+04],
#        [2.19818941e+04],
#        [3.70713879e+04],
#        [4.13296144e+04],
#        [6.23690149e+04],
#        [1.96706259e+04],
#        [3.94582946e+04],
#        [2.14271205e+04],
#        [3.92217168e+04],
#        [4.81018193e+04],
#        [7.75736728e+04],
#        [6.09799191e+03],
#        [9.05623379e+03],
#        [5.45119833e+04],
#        [4.54333244e+03],
#        [3.15120982e+04],
#        [8.20261666e+04],
#        [3.57424995e+04],
#        [5.65327660e+04],
#        [4.21328701e+04],
#        [4.18846020e+04],
#        [2.46094895e+04],
#        [2.44736414e+04],
#        [6.58087444e+04],
#        [3.25015920e+04],
#        [1.17208509e+04],
#        [1.55036484e+03],
#        [9.29880826e+04],
#        [1.44773455e+04],
#        [6.45902390e+04],
#        [5.84043869e+03],
#        [5.63031158e+04],
#        [2.96496622e+04],
#        [2.40007260e+04],
#        [6.72128383e+03],
#        [3.83053847e+04],
#        [3.81597144e+04],
#        [3.45815389e+04],
#        [2.03197768e+04],
#        [2.86894365e+04],
#        [3.26666420e+04],
#        [7.72842267e+04],
#        [7.64941442e+04],
#        [9.90767631e+02],
#        [4.36402390e+04],
#        [4.46986820e+04],
#        [3.34320759e+04],
#        [1.56478710e+04],
#        [2.26599943e+04],
#        [7.51717901e+03],
#        [1.27337722e+03],
#        [2.69339609e+04],
#        [7.16366797e+04],
#        [3.84286121e+04],
#        [1.34087994e+04],
#        [2.79069635e+04],
#        [7.82152592e+04],
#        [6.36756290e+03],
#        [1.40737686e+04],
#        [2.11131599e+04],
#        [3.65873207e+04],
#        [8.16404416e+03],
#        [1.22546045e+03],
#        [8.48282099e+03],
#        [7.46181260e+04],
#        [4.68680618e+04],
#        [2.65515005e+04],
#        [1.22323880e+04],
#        [2.46288202e+04],
#        [3.18438153e+04],
#        [1.09378577e+04],
#        [6.35642200e+04],
#        [7.38335389e+04],
#        [1.24741615e+04],
#        [1.62254604e+04],
#        [2.87723772e+04],
#        [3.28766553e+04],
#        [1.49569085e+04],
#        [4.17661599e+04],
#        [8.32792235e+04],
#        [1.88446153e+04],
#        [5.25261183e+04],
#        [5.89941392e+03],
#        [3.49825113e+04]])

# %% [markdown]
# ##### 2.5.D Find R-Square
#
# The coefficient $R^2$ is defined as $$ R^2 = 1 - \frac{SS_{res}}{SS_{tot}} $$, where $$ SS_{res} $$ is the residual sum of squares $$ SS_{res} = \sum_{i=1}^n \left(y_i - \hat{y}_i\right)^2 $$ and $$ SS_{res} $$ is the total sum of squares $$ SS_{tot} = \sum_{i=1}^n \left(y_i - \bar{y}\right)^2 $$
#
# The best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse).
#
# **Write a function to calculate R- Square value.**

# %% [markdown]
# The total sum of squares:
#
# ### $$ SS_{tot} = \sum_{i=1}^n \left(y_i - \bar{y}\right)^2 $$
#
# The residual sum of squares:
#
# ### $$ SS_{res} = \sum_{i=1}^n \left(y_i - \hat{y}_i\right)^2 $$
#
# $R^2$:
#
# ### $$ R^2 = 1 - \frac{SS_{res}}{SS_{tot}} $$

# %%
# ANSWER
ss_tot = np.sum(np.square(Y - Y.mean()))

ss_res = np.sum(np.square(Y - Y_pred))


r_squared = 1 - (ss_res/ss_tot)
r_squared
# Out:
# 0.4812307133326901

# %% [markdown]
# ##### 2.5.G [BONUS] Draw Plot of Predicted Line

# %%
# ANSWER

# %% [markdown]
# ##### 2.5.G [BONUS] Draw Plot of Predicted Line With Resudals

# %%
# ANSWER
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='green')
plt.scatter(X, res, color='red')
plt.show()

# %% [markdown]
# ### 3. Predict House Price
#
# Let's assume we have information of following house:
#
# - street:	1140 EDMONTON DR
# - city:	SACRAMENTO
# - zip:	95833
# - state:	CA
# - beds:	3
# - baths:	2
# - sq__ft:	1204
# - type:	Residential
#
# **Predict the price of this house.**

# %%
# ANSWER
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-bbfe0097954f> in <module>
#       1 # ANSWER
#       2
# ----> 3 prediction = linear_regressor.predict(1204)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     216         check_is_fitted(self)
#     217
# --> 218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     219         return safe_sparse_dot(X, self.coef_.T,
#     220                                dense_output=True) + self.intercept_
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     611             # If input is scalar raise error
#     612             if array.ndim == 0:
# --> 613                 raise ValueError(
#     614                     "Expected 2D array, got scalar array instead:\narray={}.\n"
#     615                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got scalar array instead:
# array=1204.
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Institute of Data
#
#
# ---
#
#
#
# ---
