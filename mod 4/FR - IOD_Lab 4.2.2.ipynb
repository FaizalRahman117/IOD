# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# ## Lab 4.2.2: Feature Selection

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### 1. Forward Feature Selection
#
# > Forward Selection: Forward selection is an iterative method in which we start with having no feature in the model. In each iteration, we keep adding the feature which best improves our model till an addition of a new variable does not improve the performance of the model.
#
# Create a Regression model using Forward Feature Selection by looping over all the features adding one at a time until there are no improvements on the prediction metric ( R2  and  AdjustedR2  in this case).

# %% [markdown]
# #### 1.1 Load Wine Data & Define Predictor and Target

# %%
## Load the wine quality dataset

# Load the wine dataset from csv
wine = pd.read_csv('../DATA/winequality_merged.csv')

# define the target variable (dependent variable) as y
y = wine['quality']

# Take all columns except target as predictor columns
predictor_columns = [c for c in wine.columns if c != 'quality']
# Load the dataset as a pandas data frame
X = pd.DataFrame(wine, columns = predictor_columns)

# %%
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  red_wine
# 0      9.4         1
# 1      9.8         1
# 2      9.8         1
# 3      9.8         1
# 4      9.4         1

# %%
## Create training and testing subsets
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2432            6.9             0.250         0.34             1.3      0.035
# 543            11.2             0.660         0.24             2.5      0.085
# 1616            6.2             0.660         0.48             1.2      0.029
# 6386            3.9             0.225         0.40             4.2      0.030
# 3862            6.9             0.300         0.21            15.7      0.056
# ...             ...               ...          ...             ...        ...
# 1699            7.4             0.250         0.37            13.5      0.060
# 4980            6.9             0.190         0.35             6.9      0.045
# 234             8.2             1.000         0.09             2.3      0.065
# 6150            7.0             0.230         0.32             1.8      0.048
# 4621            8.0             0.740         0.21             4.0      0.050
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2432                 27.0                  82.0  0.99045  3.18       0.44
# 543                  16.0                  53.0  0.99930  3.06       0.72
# 1616                 29.0                  75.0  0.98920  3.33       0.39
# 6386                 29.0                 118.0  0.98900  3.57       0.36
# 3862                 49.0                 159.0  0.99827  3.11       0.48
# ...                   ...                   ...      ...   ...        ...
# 1699                 52.0                 192.0  0.99750  3.00       0.44
# 4980                 51.0                 125.0  0.99330  3.10       0.44
# 234                   7.0                  37.0  0.99685  3.32       0.55
# 6150                 25.0                 113.0  0.99150  3.11       0.47
# 4621                 24.0                 133.0  0.99418  3.06       0.38
#
#       alcohol  red_wine
# 2432     12.2         0
# 543      11.0         1
# 1616     12.8         0
# 6386     12.8         0
# 3862      9.0         0
# ...       ...       ...
# 1699      9.1         0
# 4980     10.7         0
# 234       9.0         1
# 6150     11.1         0
# 4621      9.7         0
#
# [5197 rows x 12 columns]

# %% [markdown]
# #### 1.2 Overview of the code below
#
# The external `while` loop goes forever until there are no improvements to the model, which is controlled by the flag `changed` (until is **not** changed).
# The inner `for` loop goes over each of the features not yet included in the model and calculates the correlation coefficient. If any model improves on the previous best model then the records are updated.
#
# #### Code variables
# - `included`: list of the features (predictors) that were included in the model; starts empty.
# - `excluded`: list of features that have **not** been included in the model; starts as the full list of features.
# - `best`: dictionary to keep record of the best model found at any stage; starts 'empty'.
# - `model`: object of class LinearRegression, with default values for all parameters.
#
# #### Methods of the `LinearRegression` object to investigate
# - `fit()`
# - `fit.score()`
#
# #### Adjusted $R^2$ formula
# $$Adjusted \; R^2 = 1 - { (1 - R^2) (n - 1)  \over n - k - 1 }$$
#
# #### Linear Regression [reference](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression)

# %%
## Flag intermediate output

show_steps = True   # for testing/debugging
# show_steps = False  # without showing steps

# %%
## Use Forward Feature Selection to pick a good model

# start with no predictors
included = []
# keep track of model and parameters
best = {'feature': '', 'r2': 0, 'a_r2': 0}
# create a model object to hold the modelling parameters
model = LinearRegression() # create a model for Linear Regression
# get the number of cases in the test data
n = X_test.shape[0]

while True:
    changed = False
    
    if show_steps:
        print('') 

    # list the features to be evaluated
    excluded = list(set(X.columns) - set(included))
    
    if show_steps:
        print('(Step) Excluded = %s' % ', '.join(excluded))  

    # for each remaining feature to be evaluated
    for new_column in excluded:
        
        if show_steps:
            print('(Step) Trying %s...' % new_column)
            print('(Step) - Features = %s' % ', '.join(included + [new_column]))

        # fit the model with the Training data
        fit = model.fit(X_train[(included + [new_column])].values, y_train) # fit a model; consider which predictors should be included
        # calculate the score (R^2 for Regression)
        r2 = model.score(X_test[(included + [new_column])].values, y_test) # calculate the score
        # number of predictors in this model
        k = len(included + [new_column])
        # calculate the adjusted R^2
        adjusted_r2 = 1 - ((1-r2)*(n-1)/(n-k-1)) # calculate the Adjusted R^2

        if show_steps:
            print('(Step) - Adjusted R^2: This = %.3f; Best = %.3f' % 
                  (adjusted_r2, best['a_r2']))

        # if model improves
        if adjusted_r2 > best['a_r2']:
            # record new parameters
            best = {'feature': new_column, 'r2': r2, 'a_r2': adjusted_r2}
            # flag that found a better model
            changed = True
            if show_steps:
                print('(Step) - New Best!   : Feature = %s; R^2 = %.3f; Adjusted R^2 = %.3f' % 
                      (best['feature'], best['r2'], best['a_r2']))
    # END for

    # if found a better model after testing all remaining features
    if changed:
        # update control details
        included.append(best['feature'])
        excluded = list(set(excluded) - set(best['feature']))
        print('Added feature %-4s with R^2 = %.3f and adjusted R^2 = %.3f' % 
              (best['feature'], best['r2'], best['a_r2']))
    else:
        # terminate if no better model
        break

print('')
print('Resulting features:')
print(', '.join(included))
# Out:
# (Step) Excluded = density, citric acid, free sulfur dioxide, pH, residual sugar, red_wine, fixed acidity, volatile acidity, total sulfur dioxide, alcohol, sulphates, chlorides
# (Step) Trying density...
# (Step) - Features = density
# (Step) - Adjusted R^2: This = 0.105; Best = 0.000
# (Step) - New Best!   : Feature = density; R^2 = 0.106; Adjusted R^2 = 0.105
# (Step) Trying citric acid...
# (Step) - Features = citric acid
# (Step) - Adjusted R^2: This = 0.008; Best = 0.105
# (Step) Trying free sulfur dioxide...
# (Step) - Features = free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.002; Best = 0.105
# (Step) Trying pH...
# (Step) - Features = pH
# (Step) - Adjusted R^2: This = 0.000; Best = 0.105
# (Step) Trying residual sugar...
# (Step) - Features = residual sugar
# (Step) - Adjusted R^2: This = 0.002; Best = 0.105
# (Step) Trying red_wine...
# (Step) - Features = red_wine
# (Step) - Adjusted R^2: This = 0.014; Best = 0.105
# (Step) Trying fixed acidity...
# (Step) - Features = fixed acidity
# (Step) - Adjusted R^2: This = 0.008; Best = 0.105
# (Step) Trying volatile acidity...
# (Step) - Features = volatile acidity
# (Step) - Adjusted R^2: This = 0.067; Best = 0.105
# (Step) Trying total sulfur dioxide...
# (Step) - Features = total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.001; Best = 0.105
# (Step) Trying alcohol...
# (Step) - Features = alcohol
# (Step) - Adjusted R^2: This = 0.198; Best = 0.105
# (Step) - New Best!   : Feature = alcohol; R^2 = 0.199; Adjusted R^2 = 0.198
# (Step) Trying sulphates...
# (Step) - Features = sulphates
# (Step) - Adjusted R^2: This = -0.002; Best = 0.198
# (Step) Trying chlorides...
# (Step) - Features = chlorides
# (Step) - Adjusted R^2: This = 0.035; Best = 0.198
# Added feature alcohol with R^2 = 0.199 and adjusted R^2 = 0.198
#
# (Step) Excluded = density, citric acid, free sulfur dioxide, pH, residual sugar, red_wine, fixed acidity, volatile acidity, total sulfur dioxide, sulphates, chlorides
# (Step) Trying density...
# (Step) - Features = alcohol, density
# (Step) - Adjusted R^2: This = 0.197; Best = 0.198
# (Step) Trying citric acid...
# (Step) - Features = alcohol, citric acid
# (Step) - Adjusted R^2: This = 0.208; Best = 0.198
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.210; Adjusted R^2 = 0.208
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.215; Best = 0.208
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.216; Adjusted R^2 = 0.215
# (Step) Trying pH...
# (Step) - Features = alcohol, pH
# (Step) - Adjusted R^2: This = 0.195; Best = 0.215
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, residual sugar
# (Step) - Adjusted R^2: This = 0.208; Best = 0.215
# (Step) Trying red_wine...
# (Step) - Features = alcohol, red_wine
# (Step) - Adjusted R^2: This = 0.206; Best = 0.215
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, fixed acidity
# (Step) - Adjusted R^2: This = 0.200; Best = 0.215
# (Step) Trying volatile acidity...
# (Step) - Features = alcohol, volatile acidity
# (Step) - Adjusted R^2: This = 0.255; Best = 0.215
# (Step) - New Best!   : Feature = volatile acidity; R^2 = 0.257; Adjusted R^2 = 0.255
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.202; Best = 0.255
# (Step) Trying sulphates...
# (Step) - Features = alcohol, sulphates
# (Step) - Adjusted R^2: This = 0.198; Best = 0.255
# (Step) Trying chlorides...
# (Step) - Features = alcohol, chlorides
# (Step) - Adjusted R^2: This = 0.202; Best = 0.255
# Added feature volatile acidity with R^2 = 0.257 and adjusted R^2 = 0.255
#
# (Step) Excluded = density, citric acid, free sulfur dioxide, pH, residual sugar, red_wine, fixed acidity, total sulfur dioxide, sulphates, chlorides
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, density
# (Step) - Adjusted R^2: This = 0.260; Best = 0.255
# (Step) - New Best!   : Feature = density; R^2 = 0.261; Adjusted R^2 = 0.260
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, citric acid
# (Step) - Adjusted R^2: This = 0.255; Best = 0.260
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.257; Best = 0.260
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, pH
# (Step) - Adjusted R^2: This = 0.258; Best = 0.260
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, volatile acidity, residual sugar
# (Step) - Adjusted R^2: This = 0.255; Best = 0.260
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, red_wine
# (Step) - Adjusted R^2: This = 0.262; Best = 0.260
# (Step) - New Best!   : Feature = red_wine; R^2 = 0.264; Adjusted R^2 = 0.262
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, fixed acidity
# (Step) - Adjusted R^2: This = 0.254; Best = 0.262
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.257; Best = 0.262
# (Step) Trying sulphates...
# (Step) - Features = alcohol, volatile acidity, sulphates
# (Step) - Adjusted R^2: This = 0.262; Best = 0.262
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, chlorides
# (Step) - Adjusted R^2: This = 0.255; Best = 0.262
# Added feature red_wine with R^2 = 0.264 and adjusted R^2 = 0.262
#
# (Step) Excluded = density, citric acid, free sulfur dioxide, pH, residual sugar, chlorides, fixed acidity, sulphates, total sulfur dioxide
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, red_wine, density
# (Step) - Adjusted R^2: This = 0.262; Best = 0.262
# (Step) - New Best!   : Feature = density; R^2 = 0.265; Adjusted R^2 = 0.262
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, red_wine, citric acid
# (Step) - Adjusted R^2: This = 0.262; Best = 0.262
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.268; Best = 0.262
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.270; Adjusted R^2 = 0.268
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, red_wine, pH
# (Step) - Adjusted R^2: This = 0.262; Best = 0.268
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, volatile acidity, red_wine, residual sugar
# (Step) - Adjusted R^2: This = 0.266; Best = 0.268
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, red_wine, chlorides
# (Step) - Adjusted R^2: This = 0.262; Best = 0.268
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, red_wine, fixed acidity
# (Step) - Adjusted R^2: This = 0.262; Best = 0.268
# (Step) Trying sulphates...
# (Step) - Features = alcohol, volatile acidity, red_wine, sulphates
# (Step) - Adjusted R^2: This = 0.263; Best = 0.268
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, red_wine, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.261; Best = 0.268
# Added feature free sulfur dioxide with R^2 = 0.270 and adjusted R^2 = 0.268
#
# (Step) Excluded = density, citric acid, pH, chlorides, residual sugar, fixed acidity, sulphates, total sulfur dioxide
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, density
# (Step) - Adjusted R^2: This = 0.267; Best = 0.268
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, citric acid
# (Step) - Adjusted R^2: This = 0.268; Best = 0.268
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, pH
# (Step) - Adjusted R^2: This = 0.268; Best = 0.268
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, chlorides
# (Step) - Adjusted R^2: This = 0.268; Best = 0.268
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, residual sugar
# (Step) - Adjusted R^2: This = 0.270; Best = 0.268
# (Step) - New Best!   : Feature = residual sugar; R^2 = 0.272; Adjusted R^2 = 0.270
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, fixed acidity
# (Step) - Adjusted R^2: This = 0.268; Best = 0.270
# (Step) Trying sulphates...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, sulphates
# (Step) - Adjusted R^2: This = 0.269; Best = 0.270
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.270; Best = 0.270
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.273; Adjusted R^2 = 0.270
# Added feature total sulfur dioxide with R^2 = 0.273 and adjusted R^2 = 0.270
#
# (Step) Excluded = density, citric acid, pH, residual sugar, fixed acidity, sulphates, chlorides
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, density
# (Step) - Adjusted R^2: This = 0.269; Best = 0.270
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, citric acid
# (Step) - Adjusted R^2: This = 0.269; Best = 0.270
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, pH
# (Step) - Adjusted R^2: This = 0.270; Best = 0.270
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar
# (Step) - Adjusted R^2: This = 0.272; Best = 0.270
# (Step) - New Best!   : Feature = residual sugar; R^2 = 0.276; Adjusted R^2 = 0.272
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, fixed acidity
# (Step) - Adjusted R^2: This = 0.269; Best = 0.272
# (Step) Trying sulphates...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, sulphates
# (Step) - Adjusted R^2: This = 0.271; Best = 0.272
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, chlorides
# (Step) - Adjusted R^2: This = 0.270; Best = 0.272
# Added feature residual sugar with R^2 = 0.276 and adjusted R^2 = 0.272
#
# (Step) Excluded = density, citric acid, pH, fixed acidity, sulphates, chlorides
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, density
# (Step) - Adjusted R^2: This = 0.273; Best = 0.272
# (Step) - New Best!   : Feature = density; R^2 = 0.277; Adjusted R^2 = 0.273
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, citric acid
# (Step) - Adjusted R^2: This = 0.272; Best = 0.273
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, pH
# (Step) - Adjusted R^2: This = 0.274; Best = 0.273
# (Step) - New Best!   : Feature = pH; R^2 = 0.278; Adjusted R^2 = 0.274
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, fixed acidity
# (Step) - Adjusted R^2: This = 0.272; Best = 0.274
# (Step) Trying sulphates...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, sulphates
# (Step) - Adjusted R^2: This = 0.273; Best = 0.274
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, chlorides
# (Step) - Adjusted R^2: This = 0.272; Best = 0.274
# Added feature pH   with R^2 = 0.278 and adjusted R^2 = 0.274
#
# (Step) Excluded = density, citric acid, fixed acidity, sulphates, chlorides
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, pH, density
# (Step) - Adjusted R^2: This = 0.275; Best = 0.274
# (Step) - New Best!   : Feature = density; R^2 = 0.279; Adjusted R^2 = 0.275
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, pH, citric acid
# (Step) - Adjusted R^2: This = 0.273; Best = 0.275
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, pH, fixed acidity
# (Step) - Adjusted R^2: This = 0.273; Best = 0.275
# (Step) Trying sulphates...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, pH, sulphates
# (Step) - Adjusted R^2: This = 0.274; Best = 0.275
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, pH, chlorides
# (Step) - Adjusted R^2: This = 0.273; Best = 0.275
# Added feature density with R^2 = 0.279 and adjusted R^2 = 0.275
#
# (Step) Excluded = sulphates, citric acid, chlorides, fixed acidity
# (Step) Trying sulphates...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, pH, density, sulphates
# (Step) - Adjusted R^2: This = 0.277; Best = 0.275
# (Step) - New Best!   : Feature = sulphates; R^2 = 0.282; Adjusted R^2 = 0.277
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, pH, density, citric acid
# (Step) - Adjusted R^2: This = 0.274; Best = 0.277
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, pH, density, chlorides
# (Step) - Adjusted R^2: This = 0.274; Best = 0.277
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, pH, density, fixed acidity
# (Step) - Adjusted R^2: This = 0.276; Best = 0.277
# Added feature sulphates with R^2 = 0.282 and adjusted R^2 = 0.277
#
# (Step) Excluded = citric acid, chlorides, fixed acidity
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, pH, density, sulphates, citric acid
# (Step) - Adjusted R^2: This = 0.276; Best = 0.277
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, pH, density, sulphates, chlorides
# (Step) - Adjusted R^2: This = 0.277; Best = 0.277
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, pH, density, sulphates, fixed acidity
# (Step) - Adjusted R^2: This = 0.279; Best = 0.277
# (Step) - New Best!   : Feature = fixed acidity; R^2 = 0.285; Adjusted R^2 = 0.279
# Added feature fixed acidity with R^2 = 0.285 and adjusted R^2 = 0.279
#
# (Step) Excluded = citric acid, chlorides
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, pH, density, sulphates, fixed acidity, citric acid
# (Step) - Adjusted R^2: This = 0.278; Best = 0.279
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, pH, density, sulphates, fixed acidity, chlorides
# (Step) - Adjusted R^2: This = 0.279; Best = 0.279
#
# Resulting features:
# alcohol, volatile acidity, red_wine, free sulfur dioxide, total sulfur dioxide, residual sugar, pH, density, sulphates, fixed acidity

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Institute of Data
#
#
# ---
#
#
#
# ---
